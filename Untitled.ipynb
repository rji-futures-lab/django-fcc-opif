# %% [markdown]
# # Inspecting KOMU's Files
#
# This notebook is includes my initial attempts at using the FCC's [Office of Public Inspection Files APIs](https://publicfiles.fcc.gov/developer/) (OPIF). My goal is to figure out how to access political files for the 2015 election cycle.
#
# These APIs are open to the public (no authentication required), and are found under a common url path.

# %%
api_url = "https://publicfiles.fcc.gov/api/"

# %% [markdown]
# Responses can be formatted in either json or xml. I'll use json.

# %% [markdown]
# ## Dependencies

# %%
import requests
import requests_cache
from time import sleep

# %% [markdown]
# ## Set up caching

# %% [markdown]
# In order to limit my requests to the FCC's servers, I'll cache any responses I receive. We'll use [request-cache's](https://requests-cache.readthedocs.io/en/latest/) default storage backend, which is a local SQLite db, and set it to expire every 12 hours.

# %%
requests_cache.install_cache(expire_after=43200)

# %% [markdown]
# ## KOMU's Details
#
# For starters, I'm going to focus on KOMU-TV, which is located here at the University of Missouri.
#
# The OPIF Service Data API has a Facility Search endpoint. This endpoint accepts a single keyword parameter.

# %%
facility_search_endpoint = api_url + "service/facility/search/{keyword}.json"

# %%
r = requests.get(
    facility_search_endpoint.format(keyword='komu')
)

# %% [markdown]
# The results we're looking for are a couple of layers down. They include both counts and lists of entity type's found.

# %%
r.json()['results']['globalSearchResults']
# Out:
# {'tvResultsCount': 1,
#  'fmResultsCount': 0,
#  'amResultsCount': 0,
#  'cableResultsCount': 0,
#  'cableZipCodeResultsCount': 0,
#  'sdarsResultsCount': 0,
#  'dbsResultsCount': 0,
#  'tvFacilityList': [{'id': '65583',
#    'callSign': 'KOMU-TV',
#    'service': 'Digital TV',
#    'rfChannel': '8',
#    'virtualChannel': '8',
#    'licenseExpirationDate': '02/01/2022',
#    'statusDate': '06/16/2009',
#    'status': 'LICENSED',
#    'communityCity': 'COLUMBIA',
#    'communityState': 'MO',
#    'facilityType': 'CDT',
#    'frequency': '180.0',
#    'activeInd': 'Y',
#    'scannedLetterIds': '',
#    'partyName': 'THE CURATORS OF THE UNIVERSITY OF MISSOURI',
#    'partyAddress1': '1105 CARRIE FRANCKE DRIVE',
#    'partyAddress2': '',
#    'partyCity': 'COLUMBIA',
#    'partyZip1': '65211',
#    'partyZip2': '',
#    'partyState': 'MO',
#    'partyPhone': '(573)882-5768',
#    'nielsenDma': 'COLUMBIA-JEFFERSON CITY',
#    'networkAfil': 'NBC',
#    'band': 'High V',
#    'authAppId': '1316807'}],
#  'fmFacilityList': [],
#  'amFacilityList': [],
#  'cableSystemsList': [],
#  'cableSystemsZipCodeList': [],
#  'sdarsFacilityList': [],
#  'dbsFacilityList': []}

# %%
komu = r.json()['results']['globalSearchResults']['tvFacilityList'][0]

# %% [markdown]
# An important detail we'll need to hold onto is KOMU-TV's `entity_id`.

# %%
komu_id = komu['id']

# %%
komu_id
# Out:
# '65583'

# %% [markdown]
# ## KOMU's Folders

# %% [markdown]
# Each facility has a set of folders that group together similar files. This is similar to the file directory structure you find on any computer's operating system. In order to interact with the public inspection files, the FCC provides a OPIF Manager API.
#
# We can get all the folders in KOMU-TV's root directory by calling the `parentFolders` endpoint with the `entityId` and `sourceService` parameters.

# %%
parent_folders_endpoint = api_url + 'manager/folder/parentFolders.json'

# %%
payload = {'entityId': komu_id, 'sourceService': 'tv'}

# %%
r = requests.get(parent_folders_endpoint, params=payload)

# %% [markdown]
# Let's take a closer look at KOMU's folders.

# %%
for f in r.json()['folders']:
    print(f['folder_name'])
    print(f['entity_folder_id'])
    print('------------')
# Out:
# Applications and Related Materials
# 5289ec26-db91-3a1d-5513-867712eacce5
# ------------
# Basic Info
# d5d74fdb-4f3a-28b4-93e0-5ce82db90757
# ------------
# Childrens TV Programming Reports
# 1ce1d408-cf73-44c5-bd86-684d4f2b0758
# ------------
# Contour Maps
# 0dcd08f2-800e-84e9-be74-6da952e01f71
# ------------
# Equal Employment Opportunity Records
# b3878ebc-d31b-0eef-11dc-4ebc339f3498
# ------------
# FCC Authorizations
# 03fd3934-5b1f-6511-1690-657cd398e253
# ------------
# Ownership Reports
# 41c80621-9a6c-279d-49c8-23beafd16ebe
# ------------
# Political Files
# 64651c6c-e5ae-a929-b58e-31be2ba0d26b
# ------------

# %% [markdown]
# We can also just go straight to getting the "Political Files" folder info by calling the `folder/path` endpoint.

# %%
folder_path_endpoint = api_url + 'manager/folder/path.json'

# %%
payload = {
    'folderPath': 'Political Files',
    'entityId': komu_id,
    'sourceService': 'tv'
}

# %%
r = requests.get(folder_path_endpoint, params=payload)

# %%
r.json()
# Out:
# {'status': 'success',
#  'statusCode': 200,
#  'statusMessage': 'Folder found.',
#  'folder': [{'entity_folder_id': '64651c6c-e5ae-a929-b58e-31be2ba0d26b',
#    'entity_id': '65583',
#    'folder_name': 'Political Files',
#    'folder_path': 'Political Files',
#    'allow_rename_ind': 'N',
#    'allow_subfolder_ind': 'N',
#    'allow_upload_ind': 'N',
#    'allow_delete_ind': 'N',
#    'more_public_files_ind': 'N',
#    'parent_folder_id': None,
#    'file_count': None,
#    'create_ts': '2016-02-29T14:51:41-05:00',
#    'last_update_ts': '2016-02-29T14:51:41-05:00'}]}

# %% [markdown]
# Let's hold onto the id for the political folder.

# %%
komu_political_folder_id = r.json()['folder'][0]['entity_folder_id']

# %%
komu_political_folder_id
# Out:
# '64651c6c-e5ae-a929-b58e-31be2ba0d26b'

# %% [markdown]
# ## KOMU's Political Files
#
# We can get the contents of this folder using the `folder` endpoint, which requires both the `folderId` and the `entityId`.

# %%
folder_endpoint = api_url + 'manager/folder/id/{folderId}.json'

# %%
payload = {'entityId': komu_id}

# %%
r = requests.get(
    folder_endpoint.format(folderId=komu_political_folder_id),
    params=payload
)

# %% [markdown]
# Any folder has both subfolders:

# %%
subfolders = r.json()['folder']['subfolders']

# %% [markdown]
# And files:

# %%
files = r.json()['folder']['files']

# %% [markdown]
# Both of these are lists, which might be empty.

# %%
len(subfolders)
# Out:
# 9

# %%
len(files)
# Out:
# 0

# %% [markdown]
# Let's take a closer look at these subfolders.

# %%
for sf in subfolders:
    print(sf['folder_path'])
    print(sf['entity_folder_id'])
    print('file_count: {file_count}'.format(**sf))
    print('-----------------------------------------------')
# Out:
# Political Files/2012
# a53428b0-31a8-4e9c-2704-6c74d8d0298b
# file_count: 0
# -----------------------------------------------
# Political Files/2013
# 351c1159-7157-4def-b654-633265f6b90f
# file_count: 0
# -----------------------------------------------
# Political Files/2014
# be0022c5-b604-2769-1fd2-adc62db7d660
# file_count: 83
# -----------------------------------------------
# Political Files/2015
# 8529294f-b895-ca7a-31a4-b792d30c40c2
# file_count: 11
# -----------------------------------------------
# Political Files/2016
# 00897497-f06a-b4b4-c1b4-df630e88a3d8
# file_count: 373
# -----------------------------------------------
# Political Files/2017
# 55aaa1b7-7049-2ffd-85be-381bd27cd00b
# file_count: 30
# -----------------------------------------------
# Political Files/2018
# c52ea73c-7e18-d81b-8baa-fcd9f46fff7b
# file_count: 249
# -----------------------------------------------
# Political Files/2019
# b662c0a3-0dcb-cbc9-4e61-67144f7c5812
# file_count: 2
# -----------------------------------------------
# Political Files/2020
# 9e5c8718-ef44-bcd8-cf28-b5422951db33
# file_count: 0
# -----------------------------------------------

# %% [markdown]
# Now let's take a closer look at the contents of one of these folders: `Political Files/2016`.

# %%
r = requests.get(
    folder_endpoint.format(folderId="00897497-f06a-b4b4-c1b4-df630e88a3d8"),
    params=payload
)

# %%
komu_2016_political_folder = r.json()['folder']

# %% [markdown]
# Looks like it doesn't have any files.

# %%
len(komu_2016_political_folder['files'])
# Out:
# 0

# %% [markdown]
# Just more subfolders.

# %%
len(komu_2016_political_folder['subfolders'])
# Out:
# 5

# %%
for sf in komu_2016_political_folder['subfolders']:
    print(sf['folder_path'])
    print(sf['entity_folder_id'])
    print('file_count: {file_count}'.format(**sf))
    print('-----------------------------------------------')
# Out:
# Political Files/2016/Federal
# e5ecf909-3252-147d-962d-1773e7344aa0
# file_count: 48
# -----------------------------------------------
# Political Files/2016/Local
# 2f814da8-e1c6-e981-059f-c270ea4c2835
# file_count: 23
# -----------------------------------------------
# Political Files/2016/Non-Candidate Issue Ads
# 52a3207f-661d-63e8-3289-3bac17b7ed50
# file_count: 120
# -----------------------------------------------
# Political Files/2016/State
# 40d16c28-845b-9278-c3c4-5bf715f5a4f8
# file_count: 182
# -----------------------------------------------
# Political Files/2016/Terms and Disclosures
# 919a0c82-c792-bef6-5285-640458ebc916
# file_count: 0
# -----------------------------------------------

# %% [markdown]
# So now let's look in the `Political Files/2016/Federal`.

# %%
r = requests.get(
    folder_endpoint.format(folderId="e5ecf909-3252-147d-962d-1773e7344aa0"),
    params=payload
)

# %%
komu_2016_federal_political_folder = r.json()['folder']

# %% [markdown]
# Again, no files.

# %%
len(komu_2016_federal_political_folder['files'])
# Out:
# 0

# %% [markdown]
# Just more sub-folders.

# %%
len(komu_2016_federal_political_folder['subfolders'])
# Out:
# 3

# %%
for sf in komu_2016_federal_political_folder['subfolders']:
    print(sf['folder_path'])
    print(sf['entity_folder_id'])
    print('file_count: {file_count}'.format(**sf))
    print('-----------------------------------------------')
# Out:
# Political Files/2016/Federal/President
# 119a0bad-c466-acd1-6965-2d07431a827f
# file_count: 17
# -----------------------------------------------
# Political Files/2016/Federal/US House
# 57933127-b03c-bca2-5ed5-bfaefb339541
# file_count: 0
# -----------------------------------------------
# Political Files/2016/Federal/US Senate
# 73eb960e-2665-5aa3-95c4-12333931eebd
# file_count: 31
# -----------------------------------------------

# %% [markdown]
# So let's go another level down to `Political Files/2016/Federal/President`.

# %%
r = requests.get(
    folder_endpoint.format(folderId="119a0bad-c466-acd1-6965-2d07431a827f"),
    params=payload
)

# %%
komu_2016_presidential_folder = r.json()['folder']

# %% [markdown]
# Again, no files.

# %%
len(komu_2016_presidential_folder['files'])
# Out:
# 0

# %% [markdown]
# Just more subfolders.

# %%
len(komu_2016_presidential_folder['subfolders'])
# Out:
# 4

# %%
for sf in komu_2016_presidential_folder['subfolders']:
    print(sf['folder_path'])
    print(sf['entity_folder_id'])
    print('-----------------------------------------------')
# Out:
# Political Files/2016/Federal/President/Bernie Sanders
# ee229891-bf04-09bd-6ff5-9239fc974441
# -----------------------------------------------
# Political Files/2016/Federal/President/DONALD TRUMP
# 9dc7bceb-dd9a-d9b7-8269-c09d0811cda0
# -----------------------------------------------
# Political Files/2016/Federal/President/HILLARY FOR AMERICA
# 148f8d5c-af0a-c02e-41a7-2664f7fa3e6e
# -----------------------------------------------
# Political Files/2016/Federal/President/TED CRUZ 2016
# 08a1a421-2608-ed95-405e-b8ff310b61be
# -----------------------------------------------

# %% [markdown]
# Let's see what's in the 2016 Donald Trump folder.

# %%
r = requests.get(
    folder_endpoint.format(folderId="9dc7bceb-dd9a-d9b7-8269-c09d0811cda0"),
    params=payload
)

# %%
komu_2016_trump_folder = r.json()['folder']

# %%
len(komu_2016_trump_folder['files'])
# Out:
# 3

# %%
len(komu_2016_trump_folder['subfolders'])
# Out:
# 0

# %% [markdown]
# Three files and no subfolders.
#
# We can download files using the OPIF File download endpoint. Here's the url format for this endpoint:

# %%
download_url = api_url + 'manager/download/{folder_id}/{file_manager_id}.pdf'

# %%
for f in komu_2016_trump_folder['files']:
    print('''-------------------------
file_id: {file_id}
file_name: {file_name}.{file_extension}'''.format(**f)
    )
    print(download_url.format(**f))
# Out:
# -------------------------
# file_id: 3576c738-57bc-cabf-6671-4651a4a4e76d
# file_name: 38329--1.pdf
# https://publicfiles.fcc.gov/api/manager/download/9dc7bceb-dd9a-d9b7-8269-c09d0811cda0/8c68fcc4-4eed-5abf-813e-f87eb123740c.pdf
# -------------------------
# file_id: 2078cd14-0c72-bf68-6ab3-bcb2edd9aad3
# file_name: 38330--1.pdf
# https://publicfiles.fcc.gov/api/manager/download/9dc7bceb-dd9a-d9b7-8269-c09d0811cda0/e4f42749-f453-4122-0253-c0afd50c199b.pdf
# -------------------------
# file_id: c71cb9ce-7643-056d-5b5f-54fd7f2970c1
# file_name: NAB FORM.pdf
# https://publicfiles.fcc.gov/api/manager/download/9dc7bceb-dd9a-d9b7-8269-c09d0811cda0/cb412313-7757-b626-46bf-8041fc7811ae.pdf

# %% [markdown]
# The first two files are contracts between KOMU-TV and Strategic Media Services, on behalf of the adverstiser Donald Trump.
#
# The third file is a National Association of Broadcasters (NAB) Political Advertising Agreement Form (PB-18). A blank version of this form is available [here](https://gab.org/wp-content/uploads/2016/06/pb18-form-final-c1.pdf).

# %% [markdown]
# ## Getting all the service providers in Missouri

# %% [markdown]
# We can get all U.S. service providers in by type from the `facility/getall` endpoint of the OPIF Service Data API

# %%
facility_getall_endpoint = api_url + 'service/{serviceType}/facility/getall.json'

# %%
r = requests.get(facility_getall_endpoint.format(serviceType='tv'))

# %%
r.json()['message']
# Out:
# '2201 Facilities Returned'

# %%
r.json()['results']['facilityList']
# Out:
# [{'id': '-12', 'callSign': 'TV123', 'frequency': '1000.0', 'activeInd': 'N'},
#  {'id': '146', 'callSign': 'WXIN', 'frequency': '656.0', 'activeInd': 'Y'},
#  {'id': '148', 'callSign': 'KAKW-DT', 'frequency': '210.0', 'activeInd': 'Y'},
#  {'id': '414', 'callSign': 'WXLV-TV', 'frequency': '560.0', 'activeInd': 'Y'},
#  {'id': '710', 'callSign': 'WGIQ', 'frequency': '566.0', 'activeInd': 'Y'},
#  {'id': '714', 'callSign': 'WDIQ', 'frequency': '192.0', 'activeInd': 'Y'},
#  {'id': '1151', 'callSign': 'KAZQ', 'frequency': '488.0', 'activeInd': 'Y'},
#  {'id': '2506', 'callSign': 'KAPP', 'frequency': '470.0', 'activeInd': 'Y'},
#  {'id': '2770', 'callSign': 'KETS', 'frequency': '174.0', 'activeInd': 'Y'},
#  {'id': '9629', 'callSign': 'WCCO-TV', 'frequency': '578.0', 'activeInd': 'Y'},
#  {'id': '9913', 'callSign': 'WCMW', 'frequency': '506.0', 'activeInd': 'Y'},
#  {'id': '9939', 'callSign': 'WOCB-CD', 'frequency': '620.0', 'activeInd': 'Y'},
#  {'id': '417', 'callSign': 'WVAH-TV', 'frequency': '530.0', 'activeInd': 'Y'},
#  {'id': '14867', 'callSign': 'KCBA', 'frequency': '210.0', 'activeInd': 'Y'},
#  {'id': '589', 'callSign': 'WAFB', 'frequency': '186.0', 'activeInd': 'Y'},
#  {'id': '17726', 'callSign': 'WDSE', 'frequency': '180.0', 'activeInd': 'Y'},
#  {'id': '1222', 'callSign': 'WTLW', 'frequency': '66.0', 'activeInd': 'Y'},
#  {'id': '1236', 'callSign': 'KACV-TV', 'frequency': '186.0', 'activeInd': 'Y'},
#  {'id': '1255', 'callSign': 'KXTF', 'frequency': '590.0', 'activeInd': 'Y'},
#  {'id': '9987', 'callSign': 'WCVE-TV', 'frequency': '518.0', 'activeInd': 'Y'},
#  {'id': '22121', 'callSign': 'KBMY', 'frequency': '488.0', 'activeInd': 'Y'},
#  {'id': '19200', 'callSign': 'WTNZ', 'frequency': '476.0', 'activeInd': 'Y'},
#  {'id': '19653', 'callSign': 'KSBW', 'frequency': '180.0', 'activeInd': 'Y'},
#  {'id': '2722', 'callSign': 'KUAS-TV', 'frequency': '554.0', 'activeInd': 'Y'},
#  {'id': '2731', 'callSign': 'KUAT-TV', 'frequency': '566.0', 'activeInd': 'Y'},
#  {'id': '10267',
#   'callSign': 'WXYZ-TV',
#   'frequency': '632.0',
#   'activeInd': 'Y'},
#  {'id': '10869',
#   'callSign': 'WVTT-CD',
#   'frequency': '536.0',
#   'activeInd': 'Y'},
#  {'id': '11034',
#   'callSign': 'K20DN-D',
#   'frequency': '506.0',
#   'activeInd': 'Y'},
#  {'id': '11910',
#   'callSign': 'KOKI-TV',
#   'frequency': '518.0',
#   'activeInd': 'Y'},
#  {'id': '12520',
#   'callSign': 'WGMB-TV',
#   'frequency': '530.0',
#   'activeInd': 'Y'},
#  {'id': '13814', 'callSign': 'KJUD', 'frequency': '198.0', 'activeInd': 'Y'},
#  {'id': '13924',
#   'callSign': 'WPCB-TV',
#   'frequency': '554.0',
#   'activeInd': 'Y'},
#  {'id': '14682',
#   'callSign': 'WWJE-DT',
#   'frequency': '596.0',
#   'activeInd': 'Y'},
#  {'id': '16940', 'callSign': 'KBCA', 'frequency': '542.0', 'activeInd': 'Y'},
#  {'id': '18736',
#   'callSign': 'KMUM-CD',
#   'frequency': '476.0',
#   'activeInd': 'Y'},
#  {'id': '19776',
#   'callSign': 'WSUR-DT',
#   'frequency': '186.0',
#   'activeInd': 'Y'},
#  {'id': '272', 'callSign': 'WPTG-CD', 'frequency': '800.0', 'activeInd': 'Y'},
#  {'id': '415', 'callSign': 'WUTV', 'frequency': '578.0', 'activeInd': 'Y'},
#  {'id': '2768', 'callSign': 'KETG', 'frequency': '210.0', 'activeInd': 'Y'},
#  {'id': '25544', 'callSign': 'WMYV', 'frequency': '554.0', 'activeInd': 'Y'},
#  {'id': '4108', 'callSign': 'WTTA', 'frequency': '174.0', 'activeInd': 'Y'},
#  {'id': '2777', 'callSign': 'KEMV', 'frequency': '210.0', 'activeInd': 'Y'},
#  {'id': '3661', 'callSign': 'WTVW', 'frequency': '554.0', 'activeInd': 'Y'},
#  {'id': '4354', 'callSign': 'WPCT', 'frequency': '584.0', 'activeInd': 'Y'},
#  {'id': '22215', 'callSign': 'KSTU', 'frequency': '554.0', 'activeInd': 'Y'},
#  {'id': '22685',
#   'callSign': 'KBDI-TV',
#   'frequency': '210.0',
#   'activeInd': 'Y'},
#  {'id': '5010', 'callSign': 'K23EX-D', 'frequency': '524.0', 'activeInd': 'Y'},
#  {'id': '6568', 'callSign': 'WBGU-TV', 'frequency': '518.0', 'activeInd': 'Y'},
#  {'id': '6669', 'callSign': 'KBTX-TV', 'frequency': '482.0', 'activeInd': 'Y'},
#  {'id': '7078', 'callSign': 'KTPX-TV', 'frequency': '554.0', 'activeInd': 'Y'},
#  {'id': '22819', 'callSign': 'WATL', 'frequency': '536.0', 'activeInd': 'Y'},
#  {'id': '7675', 'callSign': 'KJTL', 'frequency': '476.0', 'activeInd': 'Y'},
#  {'id': '23074', 'callSign': 'KUSA', 'frequency': '186.0', 'activeInd': 'Y'},
#  {'id': '7890', 'callSign': 'KOLN', 'frequency': '192.0', 'activeInd': 'Y'},
#  {'id': '8523', 'callSign': 'KAMR-TV', 'frequency': '500.0', 'activeInd': 'Y'},
#  {'id': '8616', 'callSign': 'WPVI-TV', 'frequency': '82.0', 'activeInd': 'Y'},
#  {'id': '9754', 'callSign': 'KNCT', 'frequency': '662.0', 'activeInd': 'Y'},
#  {'id': '24766', 'callSign': 'KKCO', 'frequency': '204.0', 'activeInd': 'Y'},
#  {'id': '25683',
#   'callSign': 'WGME-TV',
#   'frequency': '476.0',
#   'activeInd': 'Y'},
#  {'id': '7692', 'callSign': 'WBPX-TV', 'frequency': '518.0', 'activeInd': 'Y'},
#  {'id': '25685', 'callSign': 'KGAN', 'frequency': '560.0', 'activeInd': 'Y'},
#  {'id': '10228', 'callSign': 'KNPB', 'frequency': '518.0', 'activeInd': 'Y'},
#  {'id': '10242', 'callSign': 'KQCA', 'frequency': '662.0', 'activeInd': 'Y'},
#  {'id': '10318',
#   'callSign': 'WBGT-CD',
#   'frequency': '626.0',
#   'activeInd': 'Y'},
#  {'id': '10645', 'callSign': 'WTVI', 'frequency': '470.0', 'activeInd': 'Y'},
#  {'id': '26249',
#   'callSign': 'KION-TV',
#   'frequency': '578.0',
#   'activeInd': 'Y'},
#  {'id': '26996',
#   'callSign': 'WYCX-CD',
#   'frequency': '680.0',
#   'activeInd': 'Y'},
#  {'id': '7726', 'callSign': 'WYME-CD', 'frequency': '', 'activeInd': 'Y'},
#  {'id': '11259', 'callSign': 'WVNY', 'frequency': '210.0', 'activeInd': 'Y'},
#  {'id': '16363', 'callSign': 'WBUI', 'frequency': '518.0', 'activeInd': 'Y'},
#  {'id': '35852', 'callSign': 'KVHP', 'frequency': '494.0', 'activeInd': 'Y'},
#  {'id': '18148', 'callSign': 'KDTV-CD', 'frequency': '', 'activeInd': 'Y'},
#  {'id': '20373', 'callSign': 'KRMZ', 'frequency': '192.0', 'activeInd': 'Y'},
#  {'id': '35313', 'callSign': 'KOB', 'frequency': '542.0', 'activeInd': 'Y'},
#  {'id': '35575', 'callSign': 'WTVX', 'frequency': '506.0', 'activeInd': 'Y'},
#  {'id': '35666', 'callSign': 'KTEN', 'frequency': '542.0', 'activeInd': 'Y'},
#  {'id': '35910',
#   'callSign': 'KHPZ-CD',
#   'frequency': '770.0',
#   'activeInd': 'Y'},
#  {'id': '8263', 'callSign': 'KAEF-TV', 'frequency': '518.0', 'activeInd': 'Y'},
#  {'id': '16517',
#   'callSign': 'WUVC-DT',
#   'frequency': '518.0',
#   'activeInd': 'Y'},
#  {'id': '35921',
#   'callSign': 'KHPM-CD',
#   'frequency': '626.0',
#   'activeInd': 'Y'},
#  {'id': '36395', 'callSign': 'WUCW', 'frequency': '518.0', 'activeInd': 'Y'},
#  {'id': '38585',
#   'callSign': 'KLMB-CD',
#   'frequency': '524.0',
#   'activeInd': 'Y'},
#  {'id': '38591',
#   'callSign': 'KLTS-TV',
#   'frequency': '488.0',
#   'activeInd': 'Y'},
#  {'id': '39649',
#   'callSign': 'WMED-TV',
#   'frequency': '192.0',
#   'activeInd': 'Y'},
#  {'id': '24783', 'callSign': 'WGVK', 'frequency': '76.0', 'activeInd': 'Y'},
#  {'id': '25452',
#   'callSign': 'KPIX-TV',
#   'frequency': '560.0',
#   'activeInd': 'Y'},
#  {'id': '39659', 'callSign': 'WCBB', 'frequency': '192.0', 'activeInd': 'Y'},
#  {'id': '39736', 'callSign': 'WFLX', 'frequency': '548.0', 'activeInd': 'Y'},
#  {'id': '40058',
#   'callSign': 'KCWT-CD',
#   'frequency': '566.0',
#   'activeInd': 'Y'},
#  {'id': '42061', 'callSign': 'WKNO', 'frequency': '560.0', 'activeInd': 'Y'},
#  {'id': '48237', 'callSign': 'WQSJ-CD', 'frequency': '', 'activeInd': 'Y'},
#  {'id': '48667', 'callSign': 'WJTV', 'frequency': '204.0', 'activeInd': 'Y'},
#  {'id': '48693',
#   'callSign': 'WHNT-TV',
#   'frequency': '500.0',
#   'activeInd': 'Y'},
#  {'id': '25932',
#   'callSign': 'WHRO-TV',
#   'frequency': '572.0',
#   'activeInd': 'Y'},
#  {'id': '57220',
#   'callSign': 'KLUZ-TV',
#   'frequency': '518.0',
#   'activeInd': 'Y'},
#  {'id': '26025', 'callSign': 'WIFS', 'frequency': '512.0', 'activeInd': 'Y'},
#  {'id': '48813',
#   'callSign': 'WUVG-DT',
#   'frequency': '674.0',
#   'activeInd': 'Y'},
#  {'id': '49397',
#   'callSign': 'KTKA-TV',
#   'frequency': '482.0',
#   'activeInd': 'Y'},
#  {'id': '55055', 'callSign': 'KXTQ-CD', 'frequency': '', 'activeInd': 'Y'},
#  {'id': '57840',
#   'callSign': 'WSLS-TV',
#   'frequency': '590.0',
#   'activeInd': 'Y'},
#  {'id': '9617', 'callSign': 'WBBM-TV', 'frequency': '204.0', 'activeInd': 'Y'},
#  {'id': '28280',
#   'callSign': 'KTFV-CD',
#   'frequency': '578.0',
#   'activeInd': 'Y'},
#  {'id': '28324', 'callSign': 'KTBU', 'frequency': '584.0', 'activeInd': 'Y'},
#  {'id': '28510',
#   'callSign': 'KSMQ-TV',
#   'frequency': '506.0',
#   'activeInd': 'Y'},
#  {'id': '29086', 'callSign': 'KYIN', 'frequency': '494.0', 'activeInd': 'Y'},
#  {'id': '61071',
#   'callSign': 'KPSD-TV',
#   'frequency': '210.0',
#   'activeInd': 'Y'},
#  {'id': '61216',
#   'callSign': 'WHIZ-TV',
#   'frequency': '626.0',
#   'activeInd': 'Y'},
#  {'id': '64547', 'callSign': 'WGRZ', 'frequency': '584.0', 'activeInd': 'Y'},
#  {'id': '64592',
#   'callSign': 'WFLA-TV',
#   'frequency': '174.0',
#   'activeInd': 'Y'},
#  {'id': '65247',
#   'callSign': 'WAWV-TV',
#   'frequency': '620.0',
#   'activeInd': 'Y'},
#  {'id': '65355',
#   'callSign': 'KTTZ-TV',
#   'frequency': '620.0',
#   'activeInd': 'Y'},
#  {'id': '66219',
#   'callSign': 'WPSU-TV',
#   'frequency': '476.0',
#   'activeInd': 'Y'},
#  {'id': '33543', 'callSign': 'KATV', 'frequency': '518.0', 'activeInd': 'Y'},
#  {'id': '66257', 'callSign': 'K49ND-D', 'frequency': '', 'activeInd': 'Y'},
#  {'id': '67022', 'callSign': 'W21CK-D', 'frequency': '82.0', 'activeInd': 'Y'},
#  {'id': '23142', 'callSign': 'WWSI', 'frequency': '590.0', 'activeInd': 'Y'},
#  {'id': '24618', 'callSign': 'WGNM', 'frequency': '584.0', 'activeInd': 'Y'},
#  {'id': '67347', 'callSign': 'KWOG', 'frequency': '560.0', 'activeInd': 'Y'},
#  {'id': '31351',
#   'callSign': 'KDFS-CD',
#   'frequency': '566.0',
#   'activeInd': 'Y'},
#  {'id': '67760',
#   'callSign': 'KTSM-TV',
#   'frequency': '482.0',
#   'activeInd': 'Y'},
#  {'id': '363', 'callSign': 'WCAV', 'frequency': '500.0', 'activeInd': 'Y'},
#  {'id': '33742',
#   'callSign': 'KCOP-TV',
#   'frequency': '210.0',
#   'activeInd': 'Y'},
#  {'id': '33756', 'callSign': 'KBZK', 'frequency': '210.0', 'activeInd': 'Y'},
#  {'id': '33764',
#   'callSign': 'KDBC-TV',
#   'frequency': '494.0',
#   'activeInd': 'Y'},
#  {'id': '33894', 'callSign': 'KCPQ', 'frequency': '210.0', 'activeInd': 'Y'},
#  {'id': '68666',
#   'callSign': 'K17GD-D',
#   'frequency': '512.0',
#   'activeInd': 'Y'},
#  {'id': '68834',
#   'callSign': 'KPXD-TV',
#   'frequency': '536.0',
#   'activeInd': 'Y'},
#  {'id': '68853',
#   'callSign': 'KEYC-TV',
#   'frequency': '204.0',
#   'activeInd': 'Y'},
#  {'id': '68886', 'callSign': 'KUTP', 'frequency': '542.0', 'activeInd': 'Y'},
#  {'id': '69080',
#   'callSign': 'WUNC-TV',
#   'frequency': '506.0',
#   'activeInd': 'Y'},
#  {'id': '69114',
#   'callSign': 'WUNE-TV',
#   'frequency': '488.0',
#   'activeInd': 'Y'},
#  {'id': '3659', 'callSign': 'KOZL-TV', 'frequency': '554.0', 'activeInd': 'Y'},
#  {'id': '24914',
#   'callSign': 'WKYT-TV',
#   'frequency': '512.0',
#   'activeInd': 'Y'},
#  {'id': '25382',
#   'callSign': 'KWTV-DT',
#   'frequency': '536.0',
#   'activeInd': 'Y'},
#  {'id': '25395', 'callSign': 'WFUP', 'frequency': '512.0', 'activeInd': 'Y'},
#  {'id': '69149',
#   'callSign': 'WUNK-TV',
#   'frequency': '524.0',
#   'activeInd': 'Y'},
#  {'id': '71353',
#   'callSign': 'WDSI-TV',
#   'frequency': '470.0',
#   'activeInd': 'Y'},
#  {'id': '4691', 'callSign': 'KDLH', 'frequency': '584.0', 'activeInd': 'Y'},
#  {'id': '71357', 'callSign': 'WDSU', 'frequency': '500.0', 'activeInd': 'Y'},
#  {'id': '71861',
#   'callSign': 'WKYU-TV',
#   'frequency': '494.0',
#   'activeInd': 'Y'},
#  {'id': '72096',
#   'callSign': 'WGBY-TV',
#   'frequency': '210.0',
#   'activeInd': 'Y'},
#  {'id': '72326',
#   'callSign': 'WHTM-TV',
#   'frequency': '192.0',
#   'activeInd': 'Y'},
#  {'id': '72338',
#   'callSign': 'WHYY-TV',
#   'frequency': '204.0',
#   'activeInd': 'Y'},
#  {'id': '22093',
#   'callSign': 'WINK-TV',
#   'frequency': '686.0',
#   'activeInd': 'Y'},
#  {'id': '3113', 'callSign': 'WVXF', 'frequency': '488.0', 'activeInd': 'Y'},
#  {'id': '21726',
#   'callSign': 'WPXX-TV',
#   'frequency': '584.0',
#   'activeInd': 'Y'},
#  {'id': '21801',
#   'callSign': 'WFSU-TV',
#   'frequency': '578.0',
#   'activeInd': 'Y'},
#  {'id': '6823', 'callSign': 'KBYU-TV', 'frequency': '488.0', 'activeInd': 'Y'},
#  {'id': '34205', 'callSign': 'WKOH', 'frequency': '488.0', 'activeInd': 'Y'},
#  {'id': '34470', 'callSign': 'KGO-TV', 'frequency': '204.0', 'activeInd': 'Y'},
#  {'id': '34529', 'callSign': 'KHOU', 'frequency': '198.0', 'activeInd': 'Y'},
#  {'id': '34847',
#   'callSign': 'KING-TV',
#   'frequency': '674.0',
#   'activeInd': 'Y'},
#  {'id': '8617', 'callSign': 'WTVD', 'frequency': '186.0', 'activeInd': 'Y'},
#  {'id': '36914',
#   'callSign': 'KGMD-TV',
#   'frequency': '186.0',
#   'activeInd': 'Y'},
#  {'id': '9990', 'callSign': 'WHTJ', 'frequency': '662.0', 'activeInd': 'Y'},
#  {'id': '10177', 'callSign': 'KTMW', 'frequency': '506.0', 'activeInd': 'Y'},
#  {'id': '35584', 'callSign': 'KSAX', 'frequency': '638.0', 'activeInd': 'Y'},
#  {'id': '35587',
#   'callSign': 'KSAZ-TV',
#   'frequency': '192.0',
#   'activeInd': 'Y'},
#  {'id': '36918',
#   'callSign': 'KGUN-TV',
#   'frequency': '186.0',
#   'activeInd': 'Y'},
#  {'id': '38336', 'callSign': 'WLIW', 'frequency': '578.0', 'activeInd': 'Y'},
#  {'id': '4152', 'callSign': 'WTVY', 'frequency': '602.0', 'activeInd': 'Y'},
#  {'id': '12497',
#   'callSign': 'WBFS-TV',
#   'frequency': '578.0',
#   'activeInd': 'Y'},
#  {'id': '42122',
#   'callSign': 'KFMB-TV',
#   'frequency': '180.0',
#   'activeInd': 'Y'},
#  {'id': '43095',
#   'callSign': 'KMTP-TV',
#   'frequency': '554.0',
#   'activeInd': 'Y'},
#  {'id': '51469',
#   'callSign': 'KZBZ-CD',
#   'frequency': '542.0',
#   'activeInd': 'Y'},
#  {'id': '31590', 'callSign': 'WCTV', 'frequency': '506.0', 'activeInd': 'Y'},
#  {'id': '31649',
#   'callSign': 'WOIL-CD',
#   'frequency': '668.0',
#   'activeInd': 'Y'},
#  {'id': '50633', 'callSign': 'KPTV', 'frequency': '204.0', 'activeInd': 'Y'},
#  {'id': '52240', 'callSign': 'WJGV-CD', 'frequency': '', 'activeInd': 'Y'},
#  {'id': '53905', 'callSign': 'WYFF', 'frequency': '602.0', 'activeInd': 'Y'},
#  {'id': '55350', 'callSign': 'WLYH', 'frequency': '566.0', 'activeInd': 'Y'},
#  {'id': '34342',
#   'callSign': 'WWDG-CD',
#   'frequency': '204.0',
#   'activeInd': 'Y'},
#  {'id': '34347',
#   'callSign': 'KOTA-TV',
#   'frequency': '174.0',
#   'activeInd': 'Y'},
#  {'id': '55370', 'callSign': 'KBRR', 'frequency': '192.0', 'activeInd': 'Y'},
#  {'id': '34439',
#   'callSign': 'KFTV-DT',
#   'frequency': '512.0',
#   'activeInd': 'Y'},
#  {'id': '55372', 'callSign': 'KVRR', 'frequency': '500.0', 'activeInd': 'Y'},
#  {'id': '55528',
#   'callSign': 'KNME-TV',
#   'frequency': '572.0',
#   'activeInd': 'Y'},
#  {'id': '55683',
#   'callSign': 'KXMD-TV',
#   'frequency': '470.0',
#   'activeInd': 'Y'},
#  {'id': '59279', 'callSign': 'WGTQ', 'frequency': '180.0', 'activeInd': 'Y'},
#  {'id': '12522',
#   'callSign': 'KWKT-TV',
#   'frequency': '554.0',
#   'activeInd': 'Y'},
#  {'id': '38586',
#   'callSign': 'WLPB-TV',
#   'frequency': '536.0',
#   'activeInd': 'Y'},
#  {'id': '38587',
#   'callSign': 'KLTL-TV',
#   'frequency': '506.0',
#   'activeInd': 'Y'},
#  {'id': '59255',
#   'callSign': 'KIVI-TV',
#   'frequency': '530.0',
#   'activeInd': 'Y'},
#  {'id': '61011',
#   'callSign': 'WRET-TV',
#   'frequency': '644.0',
#   'activeInd': 'Y'},
#  {'id': '40876', 'callSign': 'KGTV', 'frequency': '192.0', 'activeInd': 'Y'},
#  {'id': '41095',
#   'callSign': 'WRTD-CD',
#   'frequency': '746.0',
#   'activeInd': 'Y'},
#  {'id': '41125',
#   'callSign': 'K10OG-D',
#   'frequency': '192.0',
#   'activeInd': 'Y'},
#  {'id': '41223',
#   'callSign': 'KPHO-TV',
#   'frequency': '488.0',
#   'activeInd': 'Y'},
#  {'id': '64352',
#   'callSign': 'WSPX-TV',
#   'frequency': '602.0',
#   'activeInd': 'Y'},
#  {'id': '64544', 'callSign': 'KHVO', 'frequency': '210.0', 'activeInd': 'Y'},
#  {'id': '43169',
#   'callSign': 'WMAW-TV',
#   'frequency': '554.0',
#   'activeInd': 'Y'},
#  {'id': '43193',
#   'callSign': 'WMAV-TV',
#   'frequency': '602.0',
#   'activeInd': 'Y'},
#  {'id': '64833',
#   'callSign': 'WFXZ-CD',
#   'frequency': '560.0',
#   'activeInd': 'Y'},
#  {'id': '64865',
#   'callSign': 'WORA-TV',
#   'frequency': '560.0',
#   'activeInd': 'Y'},
#  {'id': '65046', 'callSign': 'WTLV', 'frequency': '210.0', 'activeInd': 'Y'},
#  {'id': '411', 'callSign': 'WRGT-TV', 'frequency': '602.0', 'activeInd': 'Y'},
#  {'id': '24570',
#   'callSign': 'K25OB-D',
#   'frequency': '728.0',
#   'activeInd': 'Y'},
#  {'id': '40861', 'callSign': 'WPXS', 'frequency': '210.0', 'activeInd': 'Y'},
#  {'id': '50170', 'callSign': 'KOCB', 'frequency': '584.0', 'activeInd': 'Y'},
#  {'id': '715', 'callSign': 'WFIQ', 'frequency': '518.0', 'activeInd': 'Y'},
#  {'id': '52888',
#   'callSign': 'KDJT-CD',
#   'frequency': '584.0',
#   'activeInd': 'Y'},
#  {'id': '54414',
#   'callSign': 'WDEM-CD',
#   'frequency': '488.0',
#   'activeInd': 'Y'},
#  {'id': '28468',
#   'callSign': 'WNPX-TV',
#   'frequency': '578.0',
#   'activeInd': 'Y'},
#  {'id': '27503',
#   'callSign': 'WKIN-CD',
#   'frequency': '174.0',
#   'activeInd': 'Y'},
#  {'id': '61551', 'callSign': 'KPIC', 'frequency': '500.0', 'activeInd': 'Y'},
#  {'id': '63162',
#   'callSign': 'KGWL-TV',
#   'frequency': '174.0',
#   'activeInd': 'Y'},
#  {'id': '55056',
#   'callSign': 'KTEL-CD',
#   'frequency': '722.0',
#   'activeInd': 'Y'},
#  {'id': '55108',
#   'callSign': 'WIRE-CD',
#   'frequency': '626.0',
#   'activeInd': 'Y'},
#  {'id': '37103', 'callSign': 'KWHD', 'frequency': '524.0', 'activeInd': 'Y'},
#  {'id': '37444', 'callSign': 'KVBI-CD', 'frequency': '', 'activeInd': 'Y'},
#  {'id': '73875',
#   'callSign': 'WPGH-TV',
#   'frequency': '644.0',
#   'activeInd': 'Y'},
#  {'id': '166534', 'callSign': 'KOHD', 'frequency': '494.0', 'activeInd': 'Y'},
#  {'id': '167765', 'callSign': 'WIIH-CD', 'frequency': '', 'activeInd': 'Y'},
#  {'id': '40619', 'callSign': 'WGPT', 'frequency': '542.0', 'activeInd': 'Y'},
#  {'id': '46753', 'callSign': 'KDAO-CD', 'frequency': '', 'activeInd': 'Y'},
#  {'id': '47981',
#   'callSign': 'KMNE-TV',
#   'frequency': '174.0',
#   'activeInd': 'Y'},
#  {'id': '48666', 'callSign': 'WECT', 'frequency': '524.0', 'activeInd': 'Y'},
#  {'id': '64033',
#   'callSign': 'WPCH-TV',
#   'frequency': '506.0',
#   'activeInd': 'Y'},
#  {'id': '64550', 'callSign': 'WQOW', 'frequency': '536.0', 'activeInd': 'Y'},
#  {'id': '65395',
#   'callSign': 'KBFD-DT',
#   'frequency': '584.0',
#   'activeInd': 'Y'},
#  {'id': '65526',
#   'callSign': 'KRON-TV',
#   'frequency': '614.0',
#   'activeInd': 'Y'},
#  {'id': '65528', 'callSign': 'WOWT', 'frequency': '518.0', 'activeInd': 'Y'},
#  {'id': '67893',
#   'callSign': 'WDLI-TV',
#   'frequency': '518.0',
#   'activeInd': 'Y'},
#  {'id': '68395',
#   'callSign': 'WBYD-CD',
#   'frequency': '596.0',
#   'activeInd': 'Y'},
#  {'id': '68433', 'callSign': 'WXMI', 'frequency': '578.0', 'activeInd': 'Y'},
#  {'id': '68541', 'callSign': 'KTRE', 'frequency': '186.0', 'activeInd': 'Y'},
#  {'id': '68547',
#   'callSign': 'WWRS-TV',
#   'frequency': '590.0',
#   'activeInd': 'Y'},
#  {'id': '69292',
#   'callSign': 'WUND-TV',
#   'frequency': '506.0',
#   'activeInd': 'Y'},
#  {'id': '69338', 'callSign': 'WEDQ', 'frequency': '590.0', 'activeInd': 'Y'},
#  {'id': '69360',
#   'callSign': 'WUNL-TV',
#   'frequency': '584.0',
#   'activeInd': 'Y'},
#  {'id': '70416',
#   'callSign': 'WBXI-CD',
#   'frequency': '668.0',
#   'activeInd': 'Y'},
#  {'id': '8564', 'callSign': 'KLRU', 'frequency': '518.0', 'activeInd': 'Y'},
#  {'id': '55685',
#   'callSign': 'KXMC-TV',
#   'frequency': '210.0',
#   'activeInd': 'Y'},
#  {'id': '70420', 'callSign': 'KBXS-CD', 'frequency': '', 'activeInd': 'Y'},
#  {'id': '69396', 'callSign': 'KUED', 'frequency': '548.0', 'activeInd': 'Y'},
#  {'id': '70428',
#   'callSign': 'WBXC-CD',
#   'frequency': '662.0',
#   'activeInd': 'Y'},
#  {'id': '70492',
#   'callSign': 'KUBE-TV',
#   'frequency': '572.0',
#   'activeInd': 'Y'},
#  {'id': '12895',
#   'callSign': 'KETH-TV',
#   'frequency': '530.0',
#   'activeInd': 'Y'},
#  {'id': '70713', 'callSign': 'WALB', 'frequency': '192.0', 'activeInd': 'Y'},
#  {'id': '70865',
#   'callSign': 'WTCN-CD',
#   'frequency': '500.0',
#   'activeInd': 'Y'},
#  {'id': '70917',
#   'callSign': 'KFXK-TV',
#   'frequency': '572.0',
#   'activeInd': 'Y'},
#  {'id': '71072',
#   'callSign': 'KORX-CD',
#   'frequency': '482.0',
#   'activeInd': 'Y'},
#  {'id': '71078',
#   'callSign': 'KKEI-CD',
#   'frequency': '722.0',
#   'activeInd': 'Y'},
#  {'id': '9628', 'callSign': 'KCBS-TV', 'frequency': '572.0', 'activeInd': 'Y'},
#  {'id': '68753', 'callSign': 'KTFN', 'frequency': '506.0', 'activeInd': 'Y'},
#  {'id': '39662', 'callSign': 'WMEM-TV', 'frequency': '', 'activeInd': 'Y'},
#  {'id': '57545',
#   'callSign': 'KLRA-CD',
#   'frequency': '518.0',
#   'activeInd': 'Y'},
#  {'id': '73881', 'callSign': 'WPIX', 'frequency': '198.0', 'activeInd': 'Y'},
#  {'id': '74098',
#   'callSign': 'WTMJ-TV',
#   'frequency': '554.0',
#   'activeInd': 'Y'},
#  {'id': '77063', 'callSign': 'KMTW', 'frequency': '596.0', 'activeInd': 'Y'},
#  {'id': '37809', 'callSign': 'WAGV', 'frequency': '470.0', 'activeInd': 'Y'},
#  {'id': '62182', 'callSign': 'KETC', 'frequency': '524.0', 'activeInd': 'Y'},
#  {'id': '77480',
#   'callSign': 'KTUZ-TV',
#   'frequency': '560.0',
#   'activeInd': 'Y'},
#  {'id': '81694',
#   'callSign': 'KGPX-TV',
#   'frequency': '590.0',
#   'activeInd': 'Y'},
#  {'id': '84214', 'callSign': 'WWTW', 'frequency': '590.0', 'activeInd': 'Y'},
#  {'id': '77483',
#   'callSign': 'KPXO-TV',
#   'frequency': '578.0',
#   'activeInd': 'Y'},
#  {'id': '21656',
#   'callSign': 'KOMO-TV',
#   'frequency': '614.0',
#   'activeInd': 'Y'},
#  {'id': '83180', 'callSign': 'KKAI', 'frequency': '560.0', 'activeInd': 'Y'},
#  {'id': '13595', 'callSign': 'WEDY', 'frequency': '656.0', 'activeInd': 'Y'},
#  {'id': '84225', 'callSign': 'KOCM', 'frequency': '482.0', 'activeInd': 'Y'},
#  {'id': '84802', 'callSign': 'WBIH', 'frequency': '560.0', 'activeInd': 'Y'},
#  {'id': '86496',
#   'callSign': 'WTPX-TV',
#   'frequency': '500.0',
#   'activeInd': 'Y'},
#  {'id': '3001', 'callSign': 'WCCV-TV', 'frequency': '596.0', 'activeInd': 'Y'},
#  {'id': '22129',
#   'callSign': 'WDAY-TV',
#   'frequency': '512.0',
#   'activeInd': 'Y'},
#  {'id': '68851',
#   'callSign': 'WWNY-TV',
#   'frequency': '174.0',
#   'activeInd': 'Y'},
#  {'id': '54280',
#   'callSign': 'WNOL-TV',
#   'frequency': '476.0',
#   'activeInd': 'Y'},
#  {'id': '58827',
#   'callSign': 'KSWB-TV',
#   'frequency': '542.0',
#   'activeInd': 'Y'},
#  {'id': '42008',
#   'callSign': 'KCWO-TV',
#   'frequency': '584.0',
#   'activeInd': 'Y'},
#  {'id': '43168',
#   'callSign': 'WMPN-TV',
#   'frequency': '506.0',
#   'activeInd': 'Y'},
#  {'id': '65749',
#   'callSign': 'WJET-TV',
#   'frequency': '554.0',
#   'activeInd': 'Y'},
#  {'id': '52953',
#   'callSign': 'KSPX-TV',
#   'frequency': '674.0',
#   'activeInd': 'Y'},
#  {'id': '53118',
#   'callSign': 'KSAT-TV',
#   'frequency': '204.0',
#   'activeInd': 'Y'},
#  {'id': '60165',
#   'callSign': 'WJAN-CD',
#   'frequency': '632.0',
#   'activeInd': 'Y'},
#  {'id': '60683', 'callSign': 'KSWK', 'frequency': '180.0', 'activeInd': 'Y'},
#  {'id': '60793', 'callSign': 'KCHF', 'frequency': '192.0', 'activeInd': 'Y'},
#  {'id': '63331',
#   'callSign': 'KOLO-TV',
#   'frequency': '180.0',
#   'activeInd': 'Y'},
#  {'id': '64338',
#   'callSign': 'WEAC-CD',
#   'frequency': '590.0',
#   'activeInd': 'Y'},
#  {'id': '64969', 'callSign': 'KVDA', 'frequency': '614.0', 'activeInd': 'Y'},
#  {'id': '65130', 'callSign': 'WQCW', 'frequency': '488.0', 'activeInd': 'Y'},
#  {'id': '71558', 'callSign': 'KSMN', 'frequency': '476.0', 'activeInd': 'Y'},
#  {'id': '167588', 'callSign': 'WYHB-CD', 'frequency': '', 'activeInd': 'Y'},
#  {'id': '70034', 'callSign': 'KMOV', 'frequency': '530.0', 'activeInd': 'Y'},
#  {'id': '70536', 'callSign': 'WSEC', 'frequency': '494.0', 'activeInd': 'Y'},
#  {'id': '71680',
#   'callSign': 'WSWP-TV',
#   'frequency': '192.0',
#   'activeInd': 'Y'},
#  {'id': '72207',
#   'callSign': 'KQEG-CD',
#   'frequency': '686.0',
#   'activeInd': 'Y'},
#  {'id': '81458', 'callSign': 'KTAZ', 'frequency': '560.0', 'activeInd': 'Y'},
#  {'id': '86205', 'callSign': 'KPIF', 'frequency': '476.0', 'activeInd': 'Y'},
#  {'id': '48659',
#   'callSign': 'KABY-TV',
#   'frequency': '186.0',
#   'activeInd': 'N'},
#  {'id': '5909', 'callSign': 'K21JQ-D', 'frequency': '518.0', 'activeInd': 'Y'},
#  {'id': '60653',
#   'callSign': 'WETM-TV',
#   'frequency': '524.0',
#   'activeInd': 'Y'},
#  {'id': '65696',
#   'callSign': 'WBAL-TV',
#   'frequency': '198.0',
#   'activeInd': 'Y'},
#  {'id': '66222',
#   'callSign': 'KFOR-TV',
#   'frequency': '548.0',
#   'activeInd': 'Y'},
#  {'id': '23338', 'callSign': 'WXBU', 'frequency': '512.0', 'activeInd': 'Y'},
#  {'id': '4148', 'callSign': 'KBAK-TV', 'frequency': '584.0', 'activeInd': 'Y'},
#  {'id': '49579', 'callSign': 'KAWB', 'frequency': '554.0', 'activeInd': 'Y'},
#  {'id': '51491', 'callSign': 'KPTM', 'frequency': '542.0', 'activeInd': 'Y'},
#  {'id': '169030',
#   'callSign': 'KBGS-TV',
#   'frequency': '482.0',
#   'activeInd': 'Y'},
#  {'id': '27290',
#   'callSign': 'WPXP-TV',
#   'frequency': '602.0',
#   'activeInd': 'Y'},
#  {'id': '28010',
#   'callSign': 'KSTP-TV',
#   'frequency': '596.0',
#   'activeInd': 'Y'},
#  {'id': '58616',
#   'callSign': 'KMMA-CD',
#   'frequency': '494.0',
#   'activeInd': 'N'},
#  {'id': '132606',
#   'callSign': 'KCGE-DT',
#   'frequency': '482.0',
#   'activeInd': 'Y'},
#  {'id': '28954', 'callSign': 'WTCV', 'frequency': '512.0', 'activeInd': 'Y'},
#  {'id': '8378', 'callSign': 'KQSL', 'frequency': '494.0', 'activeInd': 'Y'},
#  {'id': '8284', 'callSign': 'KOTI', 'frequency': '210.0', 'activeInd': 'Y'},
#  {'id': '33639', 'callSign': 'KSWT', 'frequency': '210.0', 'activeInd': 'Y'},
#  {'id': '73230',
#   'callSign': 'WLTV-DT',
#   'frequency': '524.0',
#   'activeInd': 'Y'},
#  {'id': '34207', 'callSign': 'WKLE', 'frequency': '596.0', 'activeInd': 'Y'},
#  {'id': '7623', 'callSign': 'WGTW-TV', 'frequency': '602.0', 'activeInd': 'Y'},
#  {'id': '35912',
#   'callSign': 'KHPB-CD',
#   'frequency': '482.0',
#   'activeInd': 'N'},
#  {'id': '10173',
#   'callSign': 'KTUU-TV',
#   'frequency': '192.0',
#   'activeInd': 'Y'},
#  {'id': '35652',
#   'callSign': 'KTBS-TV',
#   'frequency': '554.0',
#   'activeInd': 'Y'},
#  {'id': '24801',
#   'callSign': 'WEEK-TV',
#   'frequency': '536.0',
#   'activeInd': 'Y'},
#  {'id': '48668', 'callSign': 'WHLT', 'frequency': '518.0', 'activeInd': 'Y'},
#  {'id': '2175', 'callSign': 'WQTO', 'frequency': '500.0', 'activeInd': 'Y'},
#  {'id': '169028', 'callSign': 'KUGF-TV', 'frequency': '', 'activeInd': 'Y'},
#  {'id': '23337',
#   'callSign': 'WBNG-TV',
#   'frequency': '174.0',
#   'activeInd': 'Y'},
#  {'id': '23428', 'callSign': 'KSTW', 'frequency': '198.0', 'activeInd': 'Y'},
#  {'id': '23937', 'callSign': 'WCES-TV', 'frequency': '82.0', 'activeInd': 'Y'},
#  {'id': '25559',
#   'callSign': 'KRIS-TV',
#   'frequency': '210.0',
#   'activeInd': 'Y'},
#  {'id': '7780', 'callSign': 'WIVB-TV', 'frequency': '578.0', 'activeInd': 'Y'},
#  {'id': '27501', 'callSign': 'WKPZ-CD', 'frequency': '', 'activeInd': 'Y'},
#  {'id': '6744', 'callSign': 'WEFS', 'frequency': '566.0', 'activeInd': 'Y'},
#  {'id': '13990', 'callSign': 'WIS', 'frequency': '192.0', 'activeInd': 'Y'},
#  {'id': '35724',
#   'callSign': 'KULR-TV',
#   'frequency': '198.0',
#   'activeInd': 'Y'},
#  {'id': '282', 'callSign': 'KABC-TV', 'frequency': '174.0', 'activeInd': 'Y'},
#  {'id': '4939', 'callSign': 'KBSV', 'frequency': '476.0', 'activeInd': 'Y'},
#  {'id': '20871',
#   'callSign': 'KTFK-DT',
#   'frequency': '542.0',
#   'activeInd': 'Y'},
#  {'id': '51518', 'callSign': 'KMYS', 'frequency': '578.0', 'activeInd': 'Y'},
#  {'id': '20287',
#   'callSign': 'WATM-TV',
#   'frequency': '530.0',
#   'activeInd': 'Y'},
#  {'id': '55049',
#   'callSign': 'KASY-TV',
#   'frequency': '656.0',
#   'activeInd': 'Y'},
#  {'id': '41232',
#   'callSign': 'WSMV-TV',
#   'frequency': '192.0',
#   'activeInd': 'Y'},
#  {'id': '41315', 'callSign': 'WQED', 'frequency': '66.0', 'activeInd': 'Y'},
#  {'id': '592', 'callSign': 'KFVS-TV', 'frequency': '204.0', 'activeInd': 'Y'},
#  {'id': '33745', 'callSign': 'KNVN', 'frequency': '506.0', 'activeInd': 'Y'},
#  {'id': '68889', 'callSign': 'KTVX', 'frequency': '566.0', 'activeInd': 'Y'},
#  {'id': '594', 'callSign': 'WITN-TV', 'frequency': '590.0', 'activeInd': 'Y'},
#  {'id': '70417', 'callSign': 'WBXF-CD', 'frequency': '66.0', 'activeInd': 'Y'},
#  {'id': '4688', 'callSign': 'WHSV-TV', 'frequency': '476.0', 'activeInd': 'Y'},
#  {'id': '13815', 'callSign': 'KYUR', 'frequency': '204.0', 'activeInd': 'Y'},
#  {'id': '74449',
#   'callSign': 'KYMA-DT',
#   'frequency': '198.0',
#   'activeInd': 'Y'},
#  {'id': '166546', 'callSign': 'KSQA', 'frequency': '204.0', 'activeInd': 'Y'},
#  {'id': '167309', 'callSign': 'KNLA-CD', 'frequency': '', 'activeInd': 'Y'},
#  {'id': '12896',
#   'callSign': 'KITU-TV',
#   'frequency': '584.0',
#   'activeInd': 'Y'},
#  {'id': '54938', 'callSign': 'WAWD', 'frequency': '680.0', 'activeInd': 'Y'},
#  {'id': '4329', 'callSign': 'WVUT', 'frequency': '572.0', 'activeInd': 'Y'},
#  {'id': '49157', 'callSign': 'WCCB', 'frequency': '494.0', 'activeInd': 'Y'},
#  {'id': '34200',
#   'callSign': 'WKPI-TV',
#   'frequency': '524.0',
#   'activeInd': 'Y'},
#  {'id': '49326', 'callSign': 'KDTN', 'frequency': '560.0', 'activeInd': 'Y'},
#  {'id': '69753', 'callSign': 'KVER-CD', 'frequency': '66.0', 'activeInd': 'Y'},
#  {'id': '8620', 'callSign': 'KFSN-TV', 'frequency': '566.0', 'activeInd': 'Y'},
#  {'id': '51207',
#   'callSign': 'KDFX-CD',
#   'frequency': '626.0',
#   'activeInd': 'Y'},
#  {'id': '4297', 'callSign': 'WSIU-TV', 'frequency': '554.0', 'activeInd': 'Y'},
#  {'id': '4686', 'callSign': 'WTOK-TV', 'frequency': '210.0', 'activeInd': 'Y'},
#  {'id': '9632', 'callSign': 'KCCO-TV', 'frequency': '174.0', 'activeInd': 'N'},
#  {'id': '9739', 'callSign': 'WMCN-TV', 'frequency': '204.0', 'activeInd': 'Y'},
#  {'id': '12508',
#   'callSign': 'KOCO-TV',
#   'frequency': '174.0',
#   'activeInd': 'Y'},
#  {'id': '4318', 'callSign': 'WNMU', 'frequency': '180.0', 'activeInd': 'Y'},
#  {'id': '24977',
#   'callSign': 'KBTR-CD',
#   'frequency': '776.0',
#   'activeInd': 'Y'},
#  {'id': '49578', 'callSign': 'KAWE', 'frequency': '186.0', 'activeInd': 'Y'},
#  {'id': '13989', 'callSign': 'WAVE', 'frequency': '668.0', 'activeInd': 'Y'},
#  {'id': '53320', 'callSign': 'KGFE', 'frequency': '476.0', 'activeInd': 'Y'},
#  {'id': '54385',
#   'callSign': 'WDEF-TV',
#   'frequency': '180.0',
#   'activeInd': 'Y'},
#  {'id': '60825',
#   'callSign': 'WELF-TV',
#   'frequency': '482.0',
#   'activeInd': 'Y'},
#  {'id': '10587',
#   'callSign': 'WCBD-TV',
#   'frequency': '686.0',
#   'activeInd': 'Y'},
#  {'id': '10802', 'callSign': 'WTTW', 'frequency': '668.0', 'activeInd': 'Y'},
#  {'id': '71218',
#   'callSign': 'WBOC-TV',
#   'frequency': '578.0',
#   'activeInd': 'Y'},
#  {'id': '12427', 'callSign': 'KNDU', 'frequency': '542.0', 'activeInd': 'Y'},
#  {'id': '23277', 'callSign': 'KXVO', 'frequency': '560.0', 'activeInd': 'Y'},
#  {'id': '48658',
#   'callSign': 'KSFY-TV',
#   'frequency': '210.0',
#   'activeInd': 'Y'},
#  {'id': '50147',
#   'callSign': 'WOUB-TV',
#   'frequency': '578.0',
#   'activeInd': 'Y'},
#  {'id': '55643',
#   'callSign': 'KETK-TV',
#   'frequency': '518.0',
#   'activeInd': 'Y'},
#  {'id': '269', 'callSign': 'WQVC-CD', 'frequency': '554.0', 'activeInd': 'N'},
#  {'id': '590', 'callSign': 'WTOC-TV', 'frequency': '198.0', 'activeInd': 'Y'},
#  {'id': '51241', 'callSign': 'KALO', 'frequency': '494.0', 'activeInd': 'Y'},
#  {'id': '83943', 'callSign': 'WFNA', 'frequency': '536.0', 'activeInd': 'Y'},
#  {'id': '84215',
#   'callSign': 'KNMD-TV',
#   'frequency': '180.0',
#   'activeInd': 'Y'},
#  {'id': '26655',
#   'callSign': 'KPPX-TV',
#   'frequency': '572.0',
#   'activeInd': 'Y'},
#  {'id': '41398', 'callSign': 'WNPT', 'frequency': '180.0', 'activeInd': 'Y'},
#  {'id': '5801', 'callSign': 'KPXG-TV', 'frequency': '518.0', 'activeInd': 'Y'},
#  {'id': '73203',
#   'callSign': 'WLEX-TV',
#   'frequency': '620.0',
#   'activeInd': 'Y'},
#  {'id': '83825',
#   'callSign': 'KVME-TV',
#   'frequency': '506.0',
#   'activeInd': 'Y'},
#  {'id': '10521',
#   'callSign': 'WHDO-CD',
#   'frequency': '482.0',
#   'activeInd': 'Y'},
#  {'id': '9971', 'callSign': 'WUXP-TV', 'frequency': '512.0', 'activeInd': 'Y'},
#  {'id': '64545', 'callSign': 'WKOW', 'frequency': '542.0', 'activeInd': 'Y'},
#  {'id': '21150',
#   'callSign': 'WDMA-CD',
#   'frequency': '578.0',
#   'activeInd': 'Y'},
#  {'id': '34196', 'callSign': 'WKHA', 'frequency': '584.0', 'activeInd': 'Y'},
#  {'id': '259', 'callSign': 'WBOA-CD', 'frequency': '770.0', 'activeInd': 'N'},
#  {'id': '35092',
#   'callSign': 'WOCK-CD',
#   'frequency': '210.0',
#   'activeInd': 'Y'},
#  {'id': '35920',
#   'callSign': 'KXAN-TV',
#   'frequency': '512.0',
#   'activeInd': 'Y'},
#  {'id': '42640', 'callSign': 'KJRW', 'frequency': '488.0', 'activeInd': 'Y'},
#  {'id': '21149',
#   'callSign': 'KAJN-CD',
#   'frequency': '626.0',
#   'activeInd': 'Y'},
#  {'id': '30577',
#   'callSign': 'WUTF-TV',
#   'frequency': '500.0',
#   'activeInd': 'Y'},
#  {'id': '51597',
#   'callSign': 'WTVQ-DT',
#   'frequency': '548.0',
#   'activeInd': 'Y'},
#  {'id': '52425',
#   'callSign': 'KSJF-CD',
#   'frequency': '686.0',
#   'activeInd': 'Y'},
#  {'id': '33722', 'callSign': 'KCIT', 'frequency': '476.0', 'activeInd': 'Y'},
#  {'id': '57884',
#   'callSign': 'KUPX-TV',
#   'frequency': '560.0',
#   'activeInd': 'Y'},
#  {'id': '4190', 'callSign': 'WPBA', 'frequency': '512.0', 'activeInd': 'Y'},
#  {'id': '70596', 'callSign': 'KREX-TV', 'frequency': '54.0', 'activeInd': 'Y'},
#  {'id': '35183', 'callSign': 'KMCB', 'frequency': '518.0', 'activeInd': 'Y'},
#  {'id': '35190',
#   'callSign': 'KMTV-TV',
#   'frequency': '572.0',
#   'activeInd': 'Y'},
#  {'id': '35321', 'callSign': 'KOBF', 'frequency': '204.0', 'activeInd': 'Y'},
#  {'id': '35500', 'callSign': 'KQED', 'frequency': '566.0', 'activeInd': 'Y'},
#  {'id': '12793',
#   'callSign': 'WAXN-TV',
#   'frequency': '566.0',
#   'activeInd': 'Y'},
#  {'id': '12855',
#   'callSign': 'WUCF-TV',
#   'frequency': '524.0',
#   'activeInd': 'Y'},
#  {'id': '34348', 'callSign': 'KHSD-TV', 'frequency': '76.0', 'activeInd': 'Y'},
#  {'id': '35670', 'callSign': 'KTLA', 'frequency': '596.0', 'activeInd': 'Y'},
#  {'id': '35692', 'callSign': 'KTVE', 'frequency': '548.0', 'activeInd': 'Y'},
#  {'id': '41126',
#   'callSign': 'KLDF-CD',
#   'frequency': '488.0',
#   'activeInd': 'Y'},
#  {'id': '47070',
#   'callSign': 'KGCT-CD',
#   'frequency': '536.0',
#   'activeInd': 'Y'},
#  {'id': '10221',
#   'callSign': 'WMSN-TV',
#   'frequency': '680.0',
#   'activeInd': 'Y'},
#  {'id': '2711', 'callSign': 'WLWK-CD', 'frequency': '518.0', 'activeInd': 'Y'},
#  {'id': '2942', 'callSign': 'WPGX', 'frequency': '186.0', 'activeInd': 'Y'},
#  {'id': '21250',
#   'callSign': 'WDAM-TV',
#   'frequency': '174.0',
#   'activeInd': 'Y'},
#  {'id': '24753',
#   'callSign': 'KMOH-TV',
#   'frequency': '500.0',
#   'activeInd': 'Y'},
#  {'id': '64400',
#   'callSign': 'WBFT-CD',
#   'frequency': '662.0',
#   'activeInd': 'Y'},
#  {'id': '67792', 'callSign': 'WAQP', 'frequency': '602.0', 'activeInd': 'Y'},
#  {'id': '71130',
#   'callSign': 'WCTX-CD',
#   'frequency': '596.0',
#   'activeInd': 'N'},
#  {'id': '13960',
#   'callSign': 'WISE-TV',
#   'frequency': '590.0',
#   'activeInd': 'Y'},
#  {'id': '35882', 'callSign': 'KTFO-CD', 'frequency': '', 'activeInd': 'Y'},
#  {'id': '166512', 'callSign': 'WWJX', 'frequency': '524.0', 'activeInd': 'Y'},
#  {'id': '10549',
#   'callSign': 'WRCF-CD',
#   'frequency': '560.0',
#   'activeInd': 'Y'},
#  {'id': '41397', 'callSign': 'WFYI', 'frequency': '512.0', 'activeInd': 'Y'},
#  {'id': '42636',
#   'callSign': 'KMCI-TV',
#   'frequency': '536.0',
#   'activeInd': 'Y'},
#  {'id': '48408', 'callSign': 'WIPL', 'frequency': '530.0', 'activeInd': 'Y'},
#  {'id': '72098',
#   'callSign': 'WGBX-TV',
#   'frequency': '578.0',
#   'activeInd': 'Y'},
#  {'id': '84224', 'callSign': 'KRMU', 'frequency': '506.0', 'activeInd': 'Y'},
#  {'id': '86208', 'callSign': 'KCPM', 'frequency': '548.0', 'activeInd': 'Y'},
#  {'id': '41425', 'callSign': 'KMOT', 'frequency': '192.0', 'activeInd': 'Y'},
#  {'id': '10203',
#   'callSign': 'WSFL-TV',
#   'frequency': '548.0',
#   'activeInd': 'Y'},
#  {'id': '16530',
#   'callSign': 'WDCQ-TV',
#   'frequency': '476.0',
#   'activeInd': 'Y'},
#  {'id': '18338', 'callSign': 'KENW', 'frequency': '578.0', 'activeInd': 'Y'},
#  {'id': '24981',
#   'callSign': 'WTNO-LP',
#   'frequency': '602.0',
#   'activeInd': 'Y'},
#  {'id': '25684', 'callSign': 'WICD', 'frequency': '578.0', 'activeInd': 'Y'},
#  {'id': '608', 'callSign': 'KVTH-DT', 'frequency': '482.0', 'activeInd': 'Y'},
#  {'id': '2708', 'callSign': 'WGBA-TV', 'frequency': '470.0', 'activeInd': 'Y'},
#  {'id': '63927',
#   'callSign': 'KUVE-DT',
#   'frequency': '590.0',
#   'activeInd': 'Y'},
#  {'id': '31369', 'callSign': 'KUTU-CD', 'frequency': '', 'activeInd': 'Y'},
#  {'id': '31570', 'callSign': 'WPAN', 'frequency': '626.0', 'activeInd': 'Y'},
#  {'id': '257', 'callSign': 'WWAT-CD', 'frequency': '656.0', 'activeInd': 'Y'},
#  {'id': '334', 'callSign': 'K20JX-D', 'frequency': '548.0', 'activeInd': 'Y'},
#  {'id': '48660',
#   'callSign': 'KPRY-TV',
#   'frequency': '500.0',
#   'activeInd': 'Y'},
#  {'id': '48662',
#   'callSign': 'WSAV-TV',
#   'frequency': '620.0',
#   'activeInd': 'Y'},
#  {'id': '59139', 'callSign': 'KTVN', 'frequency': '198.0', 'activeInd': 'Y'},
#  {'id': '593', 'callSign': 'KWWL', 'frequency': '174.0', 'activeInd': 'Y'},
#  {'id': '49153',
#   'callSign': 'KTLN-TV',
#   'frequency': '638.0',
#   'activeInd': 'Y'},
#  {'id': '61961',
#   'callSign': 'KVLY-TV',
#   'frequency': '602.0',
#   'activeInd': 'Y'},
#  {'id': '71363',
#   'callSign': 'WEAR-TV',
#   'frequency': '488.0',
#   'activeInd': 'Y'},
#  {'id': '711', 'callSign': 'WCIQ', 'frequency': '204.0', 'activeInd': 'Y'},
#  {'id': '29547',
#   'callSign': 'WSBS-CD',
#   'frequency': '512.0',
#   'activeInd': 'Y'},
#  {'id': '29557',
#   'callSign': 'KNWA-TV',
#   'frequency': '584.0',
#   'activeInd': 'Y'},
#  {'id': '30283',
#   'callSign': 'WJMY-CD',
#   'frequency': '554.0',
#   'activeInd': 'Y'},
#  {'id': '31114', 'callSign': 'KLST', 'frequency': '198.0', 'activeInd': 'Y'},
#  {'id': '31437', 'callSign': 'KTVC', 'frequency': '494.0', 'activeInd': 'Y'},
#  {'id': '749', 'callSign': 'KLRN', 'frequency': '186.0', 'activeInd': 'Y'},
#  {'id': '804', 'callSign': 'KAKM', 'frequency': '180.0', 'activeInd': 'Y'},
#  {'id': '1328', 'callSign': 'WABC-TV', 'frequency': '174.0', 'activeInd': 'Y'},
#  {'id': '2130', 'callSign': 'WZRA-CD', 'frequency': '674.0', 'activeInd': 'Y'},
#  {'id': '12033', 'callSign': 'WWAY', 'frequency': '530.0', 'activeInd': 'Y'},
#  {'id': '14675', 'callSign': 'KTMF', 'frequency': '524.0', 'activeInd': 'Y'},
#  {'id': '20624',
#   'callSign': 'WMYT-TV',
#   'frequency': '668.0',
#   'activeInd': 'Y'},
#  {'id': '35685', 'callSign': 'KTUL', 'frequency': '192.0', 'activeInd': 'Y'},
#  {'id': '2709', 'callSign': 'WEUX', 'frequency': '512.0', 'activeInd': 'Y'},
#  {'id': '22590', 'callSign': 'WTVC', 'frequency': '186.0', 'activeInd': 'Y'},
#  {'id': '23079', 'callSign': 'KARE', 'frequency': '198.0', 'activeInd': 'Y'},
#  {'id': '23302', 'callSign': 'KGMC', 'frequency': '548.0', 'activeInd': 'Y'},
#  {'id': '26304', 'callSign': 'KENS', 'frequency': '620.0', 'activeInd': 'Y'},
#  {'id': '26431', 'callSign': 'KHET', 'frequency': '198.0', 'activeInd': 'Y'},
#  {'id': '26602', 'callSign': 'WELU', 'frequency': '506.0', 'activeInd': 'Y'},
#  {'id': '72362', 'callSign': 'KSNK', 'frequency': '204.0', 'activeInd': 'Y'},
#  {'id': '27245', 'callSign': 'WTGS', 'frequency': '554.0', 'activeInd': 'Y'},
#  {'id': '3032', 'callSign': 'WVUP-CD', 'frequency': '656.0', 'activeInd': 'Y'},
#  {'id': '19190', 'callSign': 'WUPW', 'frequency': '542.0', 'activeInd': 'Y'},
#  {'id': '32176', 'callSign': 'KRZG-CD', 'frequency': '', 'activeInd': 'Y'},
#  {'id': '32216',
#   'callSign': 'WUWT-CD',
#   'frequency': '632.0',
#   'activeInd': 'Y'},
#  {'id': '41110', 'callSign': 'KRCG', 'frequency': '204.0', 'activeInd': 'Y'},
#  {'id': '56032',
#   'callSign': 'KLEW-TV',
#   'frequency': '578.0',
#   'activeInd': 'Y'},
#  {'id': '56033',
#   'callSign': 'KIMA-TV',
#   'frequency': '584.0',
#   'activeInd': 'Y'},
#  {'id': '60675', 'callSign': 'KOOD', 'frequency': '482.0', 'activeInd': 'Y'},
#  {'id': '35567', 'callSign': 'KRTV', 'frequency': '174.0', 'activeInd': 'Y'},
#  {'id': '35867', 'callSign': 'KVUE', 'frequency': '584.0', 'activeInd': 'Y'},
#  {'id': '72618',
#   'callSign': 'KAZT-CD',
#   'frequency': '548.0',
#   'activeInd': 'Y'},
#  {'id': '33261',
#   'callSign': 'KADN-TV',
#   'frequency': '482.0',
#   'activeInd': 'Y'},
#  {'id': '33471', 'callSign': 'KATC', 'frequency': '554.0', 'activeInd': 'Y'},
#  {'id': '68137',
#   'callSign': 'W24BB-D',
#   'frequency': '530.0',
#   'activeInd': 'N'},
#  {'id': '4145', 'callSign': 'KAII-TV', 'frequency': '174.0', 'activeInd': 'Y'},
#  {'id': '17742',
#   'callSign': 'WYYW-CD',
#   'frequency': '722.0',
#   'activeInd': 'Y'},
#  {'id': '18267',
#   'callSign': 'WKOP-TV',
#   'frequency': '560.0',
#   'activeInd': 'Y'},
#  {'id': '18819',
#   'callSign': 'WLAE-TV',
#   'frequency': '572.0',
#   'activeInd': 'Y'},
#  {'id': '4077', 'callSign': 'WSJU-TV', 'frequency': '572.0', 'activeInd': 'N'},
#  {'id': '22124',
#   'callSign': 'WDAZ-TV',
#   'frequency': '180.0',
#   'activeInd': 'Y'},
#  {'id': '22245', 'callSign': 'WFXU', 'frequency': '674.0', 'activeInd': 'Y'},
#  {'id': '28199', 'callSign': 'WDNI-CD', 'frequency': '', 'activeInd': 'Y'},
#  {'id': '28462',
#   'callSign': 'WNDY-TV',
#   'frequency': '186.0',
#   'activeInd': 'Y'},
#  {'id': '29560',
#   'callSign': 'KFTA-TV',
#   'frequency': '548.0',
#   'activeInd': 'Y'},
#  {'id': '29712', 'callSign': 'WCWJ', 'frequency': '590.0', 'activeInd': 'Y'},
#  {'id': '30244',
#   'callSign': 'WCLL-CD',
#   'frequency': '770.0',
#   'activeInd': 'Y'},
#  {'id': '33875',
#   'callSign': 'KCRA-TV',
#   'frequency': '596.0',
#   'activeInd': 'Y'},
#  {'id': '35101', 'callSign': 'WOCH-CD', 'frequency': '', 'activeInd': 'N'},
#  {'id': '34202', 'callSign': 'WKMR', 'frequency': '566.0', 'activeInd': 'Y'},
#  {'id': '34204',
#   'callSign': 'WCVN-TV',
#   'frequency': '518.0',
#   'activeInd': 'Y'},
#  {'id': '35123',
#   'callSign': 'KMEX-DT',
#   'frequency': '590.0',
#   'activeInd': 'Y'},
#  {'id': '35131', 'callSign': 'KMID', 'frequency': '542.0', 'activeInd': 'Y'},
#  {'id': '35189', 'callSign': 'KMTR', 'frequency': '488.0', 'activeInd': 'Y'},
#  {'id': '35630', 'callSign': 'KGHZ', 'frequency': '500.0', 'activeInd': 'N'},
#  {'id': '3660', 'callSign': 'KLBK-TV', 'frequency': '572.0', 'activeInd': 'Y'},
#  {'id': '5360', 'callSign': 'WIAT', 'frequency': '566.0', 'activeInd': 'Y'},
#  {'id': '18740',
#   'callSign': 'KZMM-CD',
#   'frequency': '174.0',
#   'activeInd': 'Y'},
#  {'id': '24582',
#   'callSign': 'WHLV-TV',
#   'frequency': '692.0',
#   'activeInd': 'Y'},
#  {'id': '5982', 'callSign': 'WMSY-TV', 'frequency': '638.0', 'activeInd': 'N'},
#  {'id': '6096', 'callSign': 'WHA-TV', 'frequency': '506.0', 'activeInd': 'Y'},
#  {'id': '6463', 'callSign': 'WFXT', 'frequency': '590.0', 'activeInd': 'Y'},
#  {'id': '36838',
#   'callSign': 'WOOD-TV',
#   'frequency': '590.0',
#   'activeInd': 'Y'},
#  {'id': '37179', 'callSign': 'WLTZ', 'frequency': '596.0', 'activeInd': 'Y'},
#  {'id': '38430', 'callSign': 'KLCS', 'frequency': '554.0', 'activeInd': 'Y'},
#  {'id': '6554', 'callSign': 'WFGX', 'frequency': '686.0', 'activeInd': 'Y'},
#  {'id': '48413',
#   'callSign': 'WVMA-CD',
#   'frequency': '800.0',
#   'activeInd': 'Y'},
#  {'id': '48836',
#   'callSign': 'KXLK-CD',
#   'frequency': '788.0',
#   'activeInd': 'Y'},
#  {'id': '77451', 'callSign': 'KPTH', 'frequency': '680.0', 'activeInd': 'Y'},
#  {'id': '6863', 'callSign': 'WILX-TV', 'frequency': '192.0', 'activeInd': 'Y'},
#  {'id': '11909',
#   'callSign': 'WFOX-TV',
#   'frequency': '578.0',
#   'activeInd': 'Y'},
#  {'id': '11913', 'callSign': 'WFTC', 'frequency': '560.0', 'activeInd': 'Y'},
#  {'id': '29015', 'callSign': 'KFWD', 'frequency': '186.0', 'activeInd': 'Y'},
#  {'id': '31352',
#   'callSign': 'KTSB-CD',
#   'frequency': '596.0',
#   'activeInd': 'Y'},
#  {'id': '32334', 'callSign': 'WJYS', 'frequency': '602.0', 'activeInd': 'Y'},
#  {'id': '35883',
#   'callSign': 'KWGN-TV',
#   'frequency': '590.0',
#   'activeInd': 'Y'},
#  {'id': '35906',
#   'callSign': 'KXLT-TV',
#   'frequency': '662.0',
#   'activeInd': 'Y'},
#  {'id': '35913',
#   'callSign': 'KHPL-CD',
#   'frequency': '578.0',
#   'activeInd': 'Y'},
#  {'id': '35954', 'callSign': 'KXII', 'frequency': '204.0', 'activeInd': 'Y'},
#  {'id': '38437',
#   'callSign': 'WMDO-CD',
#   'frequency': '674.0',
#   'activeInd': 'Y'},
#  {'id': '40759',
#   'callSign': 'WTVZ-TV',
#   'frequency': '584.0',
#   'activeInd': 'Y'},
#  {'id': '42359',
#   'callSign': 'KTXD-TV',
#   'frequency': '524.0',
#   'activeInd': 'Y'},
#  {'id': '51517', 'callSign': 'KTXA', 'frequency': '494.0', 'activeInd': 'Y'},
#  {'id': '54443', 'callSign': 'WRFB', 'frequency': '566.0', 'activeInd': 'Y'},
#  {'id': '8651', 'callSign': 'KTOO-TV', 'frequency': '192.0', 'activeInd': 'Y'},
#  {'id': '35277', 'callSign': 'KNSD', 'frequency': '626.0', 'activeInd': 'Y'},
#  {'id': '36846', 'callSign': 'KWHE', 'frequency': '572.0', 'activeInd': 'Y'},
#  {'id': '455', 'callSign': 'WADL', 'frequency': '548.0', 'activeInd': 'Y'},
#  {'id': '595', 'callSign': 'WTVM', 'frequency': '198.0', 'activeInd': 'Y'},
#  {'id': '664', 'callSign': 'KSIX-TV', 'frequency': '536.0', 'activeInd': 'Y'},
#  {'id': '706', 'callSign': 'WAIQ', 'frequency': '548.0', 'activeInd': 'Y'},
#  {'id': '720', 'callSign': 'WIIQ', 'frequency': '500.0', 'activeInd': 'Y'},
#  {'id': '721', 'callSign': 'WEIQ', 'frequency': '566.0', 'activeInd': 'Y'},
#  {'id': '69479', 'callSign': 'WCTE', 'frequency': '518.0', 'activeInd': 'Y'},
#  {'id': '13456', 'callSign': 'WPBT', 'frequency': '560.0', 'activeInd': 'Y'},
#  {'id': '8688', 'callSign': 'WRAL-TV', 'frequency': '488.0', 'activeInd': 'Y'},
#  {'id': '9640', 'callSign': 'KCCW-TV', 'frequency': '204.0', 'activeInd': 'Y'},
#  {'id': '9719', 'callSign': 'KCRG-TV', 'frequency': '186.0', 'activeInd': 'Y'},
#  {'id': '9762', 'callSign': 'WGNT', 'frequency': '686.0', 'activeInd': 'Y'},
#  {'id': '10212', 'callSign': 'WOTV', 'frequency': '506.0', 'activeInd': 'Y'},
#  {'id': '12524',
#   'callSign': 'KPEJ-TV',
#   'frequency': '524.0',
#   'activeInd': 'Y'},
#  {'id': '12913',
#   'callSign': 'KLUJ-TV',
#   'frequency': '590.0',
#   'activeInd': 'Y'},
#  {'id': '13200', 'callSign': 'KUVM-CD', 'frequency': '', 'activeInd': 'Y'},
#  {'id': '34167', 'callSign': 'WBKI', 'frequency': '482.0', 'activeInd': 'Y'},
#  {'id': '34858', 'callSign': 'KTVB', 'frequency': '174.0', 'activeInd': 'Y'},
#  {'id': '9922', 'callSign': 'WCMV', 'frequency': '488.0', 'activeInd': 'Y'},
#  {'id': '29234',
#   'callSign': 'KAZA-TV',
#   'frequency': '518.0',
#   'activeInd': 'Y'},
#  {'id': '32142',
#   'callSign': 'WQQZ-CD',
#   'frequency': '584.0',
#   'activeInd': 'Y'},
#  {'id': '33710', 'callSign': 'KCCI', 'frequency': '180.0', 'activeInd': 'Y'},
#  {'id': '33770', 'callSign': 'KDFW', 'frequency': '596.0', 'activeInd': 'Y'},
#  {'id': '33778',
#   'callSign': 'KDTV-DT',
#   'frequency': '506.0',
#   'activeInd': 'Y'},
#  {'id': '10036',
#   'callSign': 'KCWC-DT',
#   'frequency': '180.0',
#   'activeInd': 'Y'},
#  {'id': '10133',
#   'callSign': 'WRAY-TV',
#   'frequency': '536.0',
#   'activeInd': 'Y'},
#  {'id': '21737', 'callSign': 'WSMH', 'frequency': '482.0', 'activeInd': 'Y'},
#  {'id': '34867', 'callSign': 'KHNL', 'frequency': '596.0', 'activeInd': 'Y'},
#  {'id': '34874', 'callSign': 'KGW', 'frequency': '180.0', 'activeInd': 'Y'},
#  {'id': '35582', 'callSign': 'WYDO', 'frequency': '668.0', 'activeInd': 'Y'},
#  {'id': '35918',
#   'callSign': 'KBVO-CD',
#   'frequency': '680.0',
#   'activeInd': 'Y'},
#  {'id': '35923',
#   'callSign': 'KHPF-CD',
#   'frequency': '734.0',
#   'activeInd': 'Y'},
#  {'id': '35991',
#   'callSign': 'KXRM-TV',
#   'frequency': '518.0',
#   'activeInd': 'Y'},
#  {'id': '35994',
#   'callSign': 'KXTX-TV',
#   'frequency': '602.0',
#   'activeInd': 'Y'},
#  {'id': '10195', 'callSign': 'KVCW', 'frequency': '560.0', 'activeInd': 'Y'},
#  {'id': '10202', 'callSign': 'KSCE', 'frequency': '512.0', 'activeInd': 'Y'},
#  {'id': '11265',
#   'callSign': 'KCAU-TV',
#   'frequency': '186.0',
#   'activeInd': 'Y'},
#  {'id': '12171',
#   'callSign': 'WDSC-TV',
#   'frequency': '530.0',
#   'activeInd': 'Y'},
#  {'id': '36841',
#   'callSign': 'WOKZ-CD',
#   'frequency': '614.0',
#   'activeInd': 'Y'},
#  {'id': '37106', 'callSign': 'WHNO', 'frequency': '512.0', 'activeInd': 'Y'},
#  {'id': '37176', 'callSign': 'WLTX', 'frequency': '476.0', 'activeInd': 'Y'},
#  {'id': '38375',
#   'callSign': 'KDEN-TV',
#   'frequency': '560.0',
#   'activeInd': 'Y'},
#  {'id': '38584',
#   'callSign': 'KMCT-TV',
#   'frequency': '614.0',
#   'activeInd': 'Y'},
#  {'id': '28119', 'callSign': 'WZDX', 'frequency': '494.0', 'activeInd': 'Y'},
#  {'id': '34174', 'callSign': 'WKMU', 'frequency': '488.0', 'activeInd': 'Y'},
#  {'id': '34212',
#   'callSign': 'WKMA-TV',
#   'frequency': '572.0',
#   'activeInd': 'Y'},
#  {'id': '34440',
#   'callSign': 'KEMO-TV',
#   'frequency': '620.0',
#   'activeInd': 'Y'},
#  {'id': '50141', 'callSign': 'WOUC-TV', 'frequency': '82.0', 'activeInd': 'Y'},
#  {'id': '50592', 'callSign': 'KTVR', 'frequency': '210.0', 'activeInd': 'Y'},
#  {'id': '51208',
#   'callSign': 'KECY-TV',
#   'frequency': '186.0',
#   'activeInd': 'Y'},
# ...
#  {'id': '48763',
#   'callSign': 'WBFL-CD',
#   'frequency': '210.0',
#   'activeInd': 'Y'},
#  {'id': '49134',
#   'callSign': 'KRDK-TV',
#   'frequency': '530.0',
#   'activeInd': 'Y'},
#  {'id': '11912',
#   'callSign': 'KAAS-TV',
#   'frequency': '488.0',
#   'activeInd': 'Y'},
#  {'id': '21536', 'callSign': 'WGWG', 'frequency': '590.0', 'activeInd': 'Y'},
#  {'id': '10259', 'callSign': 'WJAL', 'frequency': '186.0', 'activeInd': 'Y'},
#  {'id': '51189',
#   'callSign': 'KOFY-TV',
#   'frequency': '554.0',
#   'activeInd': 'Y'},
#  {'id': '51569', 'callSign': 'KTXH', 'frequency': '500.0', 'activeInd': 'Y'},
#  {'id': '53847',
#   'callSign': 'KXLN-DT',
#   'frequency': '566.0',
#   'activeInd': 'Y'},
#  {'id': '56524',
#   'callSign': 'KDNL-TV',
#   'frequency': '572.0',
#   'activeInd': 'Y'},
#  {'id': '41314',
#   'callSign': 'WINP-TV',
#   'frequency': '482.0',
#   'activeInd': 'Y'},
#  {'id': '56528', 'callSign': 'KABB', 'frequency': '566.0', 'activeInd': 'Y'},
#  {'id': '56548',
#   'callSign': 'WMYA-TV',
#   'frequency': '596.0',
#   'activeInd': 'Y'},
#  {'id': '56852',
#   'callSign': 'KWPX-TV',
#   'frequency': '584.0',
#   'activeInd': 'Y'},
#  {'id': '56971',
#   'callSign': 'KRHP-CD',
#   'frequency': '470.0',
#   'activeInd': 'Y'},
#  {'id': '57221', 'callSign': 'WRBU', 'frequency': '668.0', 'activeInd': 'Y'},
#  {'id': '57837', 'callSign': 'WUTR', 'frequency': '566.0', 'activeInd': 'Y'},
#  {'id': '57905',
#   'callSign': 'WDCO-CD',
#   'frequency': '656.0',
#   'activeInd': 'Y'},
#  {'id': '19777',
#   'callSign': 'WLII-DT',
#   'frequency': '198.0',
#   'activeInd': 'Y'},
#  {'id': '57945', 'callSign': 'KRCB', 'frequency': '76.0', 'activeInd': 'Y'},
#  {'id': '58341', 'callSign': 'WKPV', 'frequency': '668.0', 'activeInd': 'Y'},
#  {'id': '58835',
#   'callSign': 'KPXB-TV',
#   'frequency': '578.0',
#   'activeInd': 'Y'},
#  {'id': '59441',
#   'callSign': 'WEWS-TV',
#   'frequency': '476.0',
#   'activeInd': 'Y'},
#  {'id': '2787', 'callSign': 'KTHV', 'frequency': '204.0', 'activeInd': 'Y'},
#  {'id': '60026', 'callSign': 'KHTV-CD', 'frequency': '', 'activeInd': 'Y'},
#  {'id': '4349', 'callSign': 'WGSC-CD', 'frequency': '180.0', 'activeInd': 'Y'},
#  {'id': '59500',
#   'callSign': 'KFAM-CD',
#   'frequency': '734.0',
#   'activeInd': 'Y'},
#  {'id': '4585', 'callSign': 'KLFI-CD', 'frequency': '596.0', 'activeInd': 'Y'},
#  {'id': '4353', 'callSign': 'WDES-CD', 'frequency': '674.0', 'activeInd': 'Y'},
#  {'id': '86204',
#   'callSign': 'WFXS-DT',
#   'frequency': '572.0',
#   'activeInd': 'N'},
#  {'id': '4693', 'callSign': 'WYTV', 'frequency': '572.0', 'activeInd': 'Y'},
#  {'id': '60464',
#   'callSign': 'KVDF-CD',
#   'frequency': '572.0',
#   'activeInd': 'Y'},
#  {'id': '60536',
#   'callSign': 'WAMI-DT',
#   'frequency': '530.0',
#   'activeInd': 'Y'},
#  {'id': '9614', 'callSign': 'WLPH-CD', 'frequency': '', 'activeInd': 'N'},
#  {'id': '10150', 'callSign': 'KBMT', 'frequency': '204.0', 'activeInd': 'Y'},
#  {'id': '61013',
#   'callSign': 'WRLK-TV',
#   'frequency': '584.0',
#   'activeInd': 'Y'},
#  {'id': '61064',
#   'callSign': 'KDSD-TV',
#   'frequency': '488.0',
#   'activeInd': 'Y'},
#  {'id': '11113', 'callSign': 'WLGA', 'frequency': '566.0', 'activeInd': 'Y'},
#  {'id': '2784', 'callSign': 'KVTJ-DT', 'frequency': '494.0', 'activeInd': 'Y'},
#  {'id': '10245',
#   'callSign': 'KCEN-TV',
#   'frequency': '186.0',
#   'activeInd': 'Y'},
#  {'id': '61068',
#   'callSign': 'KBHE-TV',
#   'frequency': '542.0',
#   'activeInd': 'Y'},
#  {'id': '61217', 'callSign': 'WNKY', 'frequency': '530.0', 'activeInd': 'Y'},
#  {'id': '61573', 'callSign': 'WVEO', 'frequency': '488.0', 'activeInd': 'Y'},
#  {'id': '191340', 'callSign': 'WTSD-CD', 'frequency': '', 'activeInd': 'N'},
#  {'id': '13938', 'callSign': 'WUPL', 'frequency': '488.0', 'activeInd': 'Y'},
#  {'id': '14326',
#   'callSign': 'WBNF-CD',
#   'frequency': '476.0',
#   'activeInd': 'Y'},
#  {'id': '15507', 'callSign': 'WZBJ', 'frequency': '494.0', 'activeInd': 'Y'},
#  {'id': '63158',
#   'callSign': 'KCDO-TV',
#   'frequency': '524.0',
#   'activeInd': 'Y'},
#  {'id': '64444', 'callSign': 'KCWE', 'frequency': '572.0', 'activeInd': 'Y'},
#  {'id': '64596',
#   'callSign': 'KXDF-CD',
#   'frequency': '210.0',
#   'activeInd': 'Y'},
#  {'id': '64864',
#   'callSign': 'W10BG-D',
#   'frequency': '192.0',
#   'activeInd': 'Y'},
#  {'id': '21160',
#   'callSign': 'KHGI-TV',
#   'frequency': '210.0',
#   'activeInd': 'Y'},
#  {'id': '64546', 'callSign': 'WAOW', 'frequency': '186.0', 'activeInd': 'Y'},
#  {'id': '64549', 'callSign': 'WXOW', 'frequency': '554.0', 'activeInd': 'Y'},
#  {'id': '46728',
#   'callSign': 'WCAX-TV',
#   'frequency': '518.0',
#   'activeInd': 'Y'},
#  {'id': '65128', 'callSign': 'WHDF', 'frequency': '54.0', 'activeInd': 'Y'},
#  {'id': '51806',
#   'callSign': 'WBXH-CD',
#   'frequency': '662.0',
#   'activeInd': 'Y'},
#  {'id': '65670',
#   'callSign': 'WETA-TV',
#   'frequency': '572.0',
#   'activeInd': 'Y'},
#  {'id': '65690', 'callSign': 'WDTN', 'frequency': '572.0', 'activeInd': 'Y'},
#  {'id': '22206', 'callSign': 'WNYW', 'frequency': '650.0', 'activeInd': 'Y'},
#  {'id': '33078', 'callSign': 'KVTV', 'frequency': '210.0', 'activeInd': 'N'},
#  {'id': '24485', 'callSign': 'KGEB', 'frequency': '204.0', 'activeInd': 'Y'},
#  {'id': '66285',
#   'callSign': 'WGTE-TV',
#   'frequency': '560.0',
#   'activeInd': 'Y'},
#  {'id': '66398', 'callSign': 'WMBB', 'frequency': '210.0', 'activeInd': 'Y'},
#  {'id': '66413',
#   'callSign': 'KWCH-DT',
#   'frequency': '500.0',
#   'activeInd': 'Y'},
#  {'id': '7651', 'callSign': 'WJFB', 'frequency': '650.0', 'activeInd': 'Y'},
#  {'id': '19184', 'callSign': 'WMC-TV', 'frequency': '76.0', 'activeInd': 'Y'},
#  {'id': '67020',
#   'callSign': 'W34EY-D',
#   'frequency': '614.0',
#   'activeInd': 'Y'},
#  {'id': '23341',
#   'callSign': 'WTAJ-TV',
#   'frequency': '530.0',
#   'activeInd': 'Y'},
#  {'id': '23394', 'callSign': 'KIAH', 'frequency': '590.0', 'activeInd': 'Y'},
#  {'id': '66804',
#   'callSign': 'WOAY-TV',
#   'frequency': '686.0',
#   'activeInd': 'Y'},
#  {'id': '66908',
#   'callSign': 'WTWC-TV',
#   'frequency': '626.0',
#   'activeInd': 'Y'},
#  {'id': '23948', 'callSign': 'WGTV', 'frequency': '174.0', 'activeInd': 'Y'},
#  {'id': '67784',
#   'callSign': 'WNYO-TV',
#   'frequency': '680.0',
#   'activeInd': 'Y'},
#  {'id': '67787', 'callSign': 'WINM', 'frequency': '204.0', 'activeInd': 'Y'},
#  {'id': '23930',
#   'callSign': 'WACS-TV',
#   'frequency': '174.0',
#   'activeInd': 'Y'},
#  {'id': '23935',
#   'callSign': 'WMUM-TV',
#   'frequency': '186.0',
#   'activeInd': 'Y'},
#  {'id': '23942', 'callSign': 'WNGH-TV', 'frequency': '66.0', 'activeInd': 'Y'},
#  {'id': '23947',
#   'callSign': 'WVAN-TV',
#   'frequency': '180.0',
#   'activeInd': 'Y'},
#  {'id': '361', 'callSign': 'WACY-TV', 'frequency': '602.0', 'activeInd': 'Y'},
#  {'id': '24215', 'callSign': 'WEHT', 'frequency': '204.0', 'activeInd': 'Y'},
#  {'id': '24257',
#   'callSign': 'W47EI-D',
#   'frequency': '680.0',
#   'activeInd': 'Y'},
#  {'id': '24287', 'callSign': 'KXGN-TV', 'frequency': '76.0', 'activeInd': 'Y'},
#  {'id': '48663',
#   'callSign': 'KOLD-TV',
#   'frequency': '578.0',
#   'activeInd': 'Y'},
#  {'id': '67884',
#   'callSign': 'KTBN-TV',
#   'frequency': '584.0',
#   'activeInd': 'Y'},
#  {'id': '24436', 'callSign': 'KLTJ', 'frequency': '524.0', 'activeInd': 'Y'},
#  {'id': '67950',
#   'callSign': 'KTBW-TV',
#   'frequency': '470.0',
#   'activeInd': 'Y'},
#  {'id': '67971',
#   'callSign': 'WHFT-TV',
#   'frequency': '662.0',
#   'activeInd': 'Y'},
#  {'id': '24508',
#   'callSign': 'KHSL-TV',
#   'frequency': '494.0',
#   'activeInd': 'Y'},
#  {'id': '24514',
#   'callSign': 'KTFD-TV',
#   'frequency': '542.0',
#   'activeInd': 'Y'},
#  {'id': '67910',
#   'callSign': 'KDTX-TV',
#   'frequency': '512.0',
#   'activeInd': 'Y'},
#  {'id': '68403', 'callSign': 'WTOO-CD', 'frequency': '', 'activeInd': 'Y'},
#  {'id': '14674', 'callSign': 'KWYB', 'frequency': '500.0', 'activeInd': 'Y'},
#  {'id': '16930', 'callSign': 'KLEG-CD', 'frequency': '', 'activeInd': 'Y'},
#  {'id': '18252',
#   'callSign': 'WETP-TV',
#   'frequency': '530.0',
#   'activeInd': 'Y'},
#  {'id': '68135',
#   'callSign': 'WYLN-LP',
#   'frequency': '596.0',
#   'activeInd': 'Y'},
#  {'id': '68143', 'callSign': 'W09DB-D', 'frequency': '76.0', 'activeInd': 'Y'},
#  {'id': '68542', 'callSign': 'WLBT', 'frequency': '566.0', 'activeInd': 'Y'},
#  {'id': '147', 'callSign': 'WTIC-TV', 'frequency': '590.0', 'activeInd': 'Y'},
#  {'id': '267', 'callSign': 'WWLM-CD', 'frequency': '506.0', 'activeInd': 'Y'},
#  {'id': '68538',
#   'callSign': 'KRHD-CD',
#   'frequency': '590.0',
#   'activeInd': 'Y'},
#  {'id': '68540', 'callSign': 'KLTV', 'frequency': '174.0', 'activeInd': 'Y'},
#  {'id': '701', 'callSign': 'WAKA', 'frequency': '638.0', 'activeInd': 'Y'},
#  {'id': '717', 'callSign': 'WBIQ', 'frequency': '192.0', 'activeInd': 'Y'},
#  {'id': '68581', 'callSign': 'KTVD', 'frequency': '572.0', 'activeInd': 'Y'},
#  {'id': '607', 'callSign': 'KVTN-DT', 'frequency': '530.0', 'activeInd': 'Y'},
#  {'id': '617', 'callSign': 'WTVU-CD', 'frequency': '722.0', 'activeInd': 'Y'},
#  {'id': '1005', 'callSign': 'KDOR-TV', 'frequency': '602.0', 'activeInd': 'Y'},
#  {'id': '1002', 'callSign': 'WTJP-TV', 'frequency': '542.0', 'activeInd': 'Y'},
#  {'id': '2495', 'callSign': 'KVEW', 'frequency': '548.0', 'activeInd': 'Y'},
#  {'id': '69170', 'callSign': 'KTSC', 'frequency': '180.0', 'activeInd': 'Y'},
#  {'id': '2455', 'callSign': 'WCYB-TV', 'frequency': '596.0', 'activeInd': 'Y'},
#  {'id': '3133', 'callSign': 'WWMB', 'frequency': '542.0', 'activeInd': 'Y'},
#  {'id': '3228', 'callSign': 'WFXG', 'frequency': '572.0', 'activeInd': 'Y'},
#  {'id': '21729',
#   'callSign': 'WPXL-TV',
#   'frequency': '686.0',
#   'activeInd': 'Y'},
#  {'id': '24218',
#   'callSign': 'KWBJ-CD',
#   'frequency': '620.0',
#   'activeInd': 'Y'},
#  {'id': '41429',
#   'callSign': 'KUMV-TV',
#   'frequency': '180.0',
#   'activeInd': 'Y'},
#  {'id': '3359', 'callSign': 'WRBL', 'frequency': '476.0', 'activeInd': 'Y'},
#  {'id': '69582', 'callSign': 'KUEN', 'frequency': '602.0', 'activeInd': 'Y'},
#  {'id': '69733', 'callSign': 'KVPT', 'frequency': '578.0', 'activeInd': 'Y'},
#  {'id': '4149', 'callSign': 'WVUE-DT', 'frequency': '560.0', 'activeInd': 'Y'},
#  {'id': '4326', 'callSign': 'KMOS-TV', 'frequency': '476.0', 'activeInd': 'Y'},
#  {'id': '4754', 'callSign': 'WJKF-CD', 'frequency': '186.0', 'activeInd': 'Y'},
#  {'id': '70414',
#   'callSign': 'WBXJ-CD',
#   'frequency': '192.0',
#   'activeInd': 'Y'},
#  {'id': '5914', 'callSign': 'K31KL-D', 'frequency': '554.0', 'activeInd': 'Y'},
#  {'id': '6104', 'callSign': 'WKAR-TV', 'frequency': '578.0', 'activeInd': 'Y'},
#  {'id': '6359', 'callSign': 'KSL-TV', 'frequency': '524.0', 'activeInd': 'Y'},
#  {'id': '349', 'callSign': 'KDCG-CD', 'frequency': '518.0', 'activeInd': 'Y'},
#  {'id': '70423',
#   'callSign': 'WUBX-CD',
#   'frequency': '210.0',
#   'activeInd': 'Y'},
#  {'id': '9635', 'callSign': 'WFRV-TV', 'frequency': '518.0', 'activeInd': 'Y'},
#  {'id': '9781', 'callSign': 'KXXV', 'frequency': '542.0', 'activeInd': 'Y'},
#  {'id': '9881', 'callSign': 'WTGL', 'frequency': '662.0', 'activeInd': 'Y'},
#  {'id': '9908', 'callSign': 'WCMU-TV', 'frequency': '542.0', 'activeInd': 'Y'},
#  {'id': '25221', 'callSign': 'KDMD', 'frequency': '584.0', 'activeInd': 'Y'},
#  {'id': '61173',
#   'callSign': 'KPXL-TV',
#   'frequency': '542.0',
#   'activeInd': 'Y'},
#  {'id': '9917', 'callSign': 'WCML', 'frequency': '530.0', 'activeInd': 'Y'},
#  {'id': '10019', 'callSign': 'WNVT', 'frequency': '566.0', 'activeInd': 'Y'},
#  {'id': '10179', 'callSign': 'KSNV', 'frequency': '584.0', 'activeInd': 'Y'},
#  {'id': '10253',
#   'callSign': 'WIPX-TV',
#   'frequency': '548.0',
#   'activeInd': 'Y'},
#  {'id': '10265',
#   'callSign': 'KOHC-CD',
#   'frequency': '174.0',
#   'activeInd': 'Y'},
#  {'id': '10981',
#   'callSign': 'WCPX-TV',
#   'frequency': '644.0',
#   'activeInd': 'Y'},
#  {'id': '11033', 'callSign': 'WLLA', 'frequency': '518.0', 'activeInd': 'Y'},
#  {'id': '66407', 'callSign': 'WBTW', 'frequency': '210.0', 'activeInd': 'Y'},
#  {'id': '998', 'callSign': 'WWTO-TV', 'frequency': '596.0', 'activeInd': 'Y'},
#  {'id': '2370', 'callSign': 'WSVI', 'frequency': '506.0', 'activeInd': 'Y'},
#  {'id': '2728', 'callSign': 'KAET', 'frequency': '180.0', 'activeInd': 'Y'},
#  {'id': '8309', 'callSign': 'K32DY-D', 'frequency': '578.0', 'activeInd': 'Y'},
#  {'id': '7893', 'callSign': 'WEAU', 'frequency': '566.0', 'activeInd': 'N'},
#  {'id': '9630', 'callSign': 'WJMN-TV', 'frequency': '578.0', 'activeInd': 'Y'},
#  {'id': '13950',
#   'callSign': 'WHBF-TV',
#   'frequency': '500.0',
#   'activeInd': 'Y'},
#  {'id': '66321',
#   'callSign': 'K35DG-D',
#   'frequency': '596.0',
#   'activeInd': 'N'},
#  {'id': '14885',
#   'callSign': 'KUOK-CD',
#   'frequency': '740.0',
#   'activeInd': 'Y'},
#  {'id': '16820', 'callSign': 'WABM', 'frequency': '602.0', 'activeInd': 'Y'},
#  {'id': '17399',
#   'callSign': 'K33EJ-D',
#   'frequency': '584.0',
#   'activeInd': 'Y'},
#  {'id': '65143',
#   'callSign': 'WISC-TV',
#   'frequency': '198.0',
#   'activeInd': 'Y'},
#  {'id': '65301',
#   'callSign': 'KAMU-TV',
#   'frequency': '204.0',
#   'activeInd': 'Y'},
#  {'id': '17680',
#   'callSign': 'KSGW-TV',
#   'frequency': '210.0',
#   'activeInd': 'Y'},
#  {'id': '306', 'callSign': 'KRBC-TV', 'frequency': '560.0', 'activeInd': 'Y'},
#  {'id': '307', 'callSign': 'KSAN-TV', 'frequency': '482.0', 'activeInd': 'Y'},
#  {'id': '591', 'callSign': 'WAFF', 'frequency': '476.0', 'activeInd': 'Y'},
#  {'id': '1270', 'callSign': 'KPVI-DT', 'frequency': '524.0', 'activeInd': 'Y'},
#  {'id': '20818',
#   'callSign': 'WNYJ-TV',
#   'frequency': '560.0',
#   'activeInd': 'N'},
#  {'id': '1051', 'callSign': 'WJLA-TV', 'frequency': '174.0', 'activeInd': 'Y'},
#  {'id': '2174', 'callSign': 'WMTJ', 'frequency': '476.0', 'activeInd': 'Y'},
#  {'id': '308', 'callSign': 'KTXS-TV', 'frequency': '506.0', 'activeInd': 'Y'},
#  {'id': '713', 'callSign': 'WHIQ', 'frequency': '530.0', 'activeInd': 'Y'},
#  {'id': '4685', 'callSign': 'WTAP-TV', 'frequency': '596.0', 'activeInd': 'Y'},
#  {'id': '67895',
#   'callSign': 'WOMS-CD',
#   'frequency': '560.0',
#   'activeInd': 'Y'},
#  {'id': '68549',
#   'callSign': 'WOHL-CD',
#   'frequency': '536.0',
#   'activeInd': 'Y'},
#  {'id': '8214', 'callSign': 'KQET', 'frequency': '536.0', 'activeInd': 'Y'},
#  {'id': '8257', 'callSign': 'K19GH-D', 'frequency': '728.0', 'activeInd': 'Y'},
#  {'id': '8260', 'callSign': 'KOBI', 'frequency': '76.0', 'activeInd': 'Y'},
#  {'id': '8291', 'callSign': 'KRCR-TV', 'frequency': '174.0', 'activeInd': 'Y'},
#  {'id': '8322', 'callSign': 'KLSR-TV', 'frequency': '572.0', 'activeInd': 'Y'},
#  {'id': '9375', 'callSign': 'KEFN-CD', 'frequency': '', 'activeInd': 'Y'},
#  {'id': '5237', 'callSign': 'KYUS-TV', 'frequency': '60.0', 'activeInd': 'Y'},
#  {'id': '10073',
#   'callSign': 'WTMO-CD',
#   'frequency': '572.0',
#   'activeInd': 'Y'},
#  {'id': '10132',
#   'callSign': 'WFFF-TV',
#   'frequency': '482.0',
#   'activeInd': 'Y'},
#  {'id': '3086', 'callSign': 'WTZT-CD', 'frequency': '554.0', 'activeInd': 'Y'},
#  {'id': '3255', 'callSign': 'WQHA', 'frequency': '536.0', 'activeInd': 'Y'},
#  {'id': '3667', 'callSign': 'WVII-TV', 'frequency': '174.0', 'activeInd': 'Y'},
#  {'id': '4366', 'callSign': 'WURH-CD', 'frequency': '536.0', 'activeInd': 'Y'},
#  {'id': '13988', 'callSign': 'KAIT', 'frequency': '180.0', 'activeInd': 'Y'},
#  {'id': '14000', 'callSign': 'KJLA', 'frequency': '692.0', 'activeInd': 'Y'},
#  {'id': '16817', 'callSign': 'WTVS', 'frequency': '506.0', 'activeInd': 'Y'},
#  {'id': '68939',
#   'callSign': 'WILL-TV',
#   'frequency': '186.0',
#   'activeInd': 'Y'},
#  {'id': '69300',
#   'callSign': 'WUNF-TV',
#   'frequency': '536.0',
#   'activeInd': 'Y'},
#  {'id': '16455', 'callSign': 'WMDT', 'frequency': '560.0', 'activeInd': 'Y'},
#  {'id': '17830',
#   'callSign': 'KGMM-CD',
#   'frequency': '734.0',
#   'activeInd': 'Y'},
#  {'id': '18283',
#   'callSign': 'KODE-TV',
#   'frequency': '524.0',
#   'activeInd': 'Y'},
#  {'id': '19199', 'callSign': 'WACH', 'frequency': '518.0', 'activeInd': 'Y'},
#  {'id': '69397',
#   'callSign': 'WUNP-TV',
#   'frequency': '548.0',
#   'activeInd': 'Y'},
#  {'id': '69416', 'callSign': 'WUNU', 'frequency': '566.0', 'activeInd': 'Y'},
#  {'id': '19561', 'callSign': 'WECN', 'frequency': '494.0', 'activeInd': 'Y'},
#  {'id': '21161', 'callSign': 'KSNB-TV', 'frequency': '66.0', 'activeInd': 'Y'},
#  {'id': '21258', 'callSign': 'WSES', 'frequency': '584.0', 'activeInd': 'Y'},
#  ...]

# %% [markdown]
# Sadly, the response doesn't include any location info for each station.

# %% [markdown]
# ## Glossary
#
# **OPIF:** Office of Public Inspection Files
#
# **SDARS Data:** Satellite Digital Audio Radio Service
#
# **DBS Data:** Direct Broadcast Satellite
#
# **frn:** FCC Registration Number

# %% [markdown]
# ## Questions
#
# 1. Does every TV station, radio station, or other service provide follow the same directory structure?
# 2. Are there other important types of files to collect (besides the contract agreements and the NAB forms)?
# 3. How similar are the contract agreements upload from other stations?
